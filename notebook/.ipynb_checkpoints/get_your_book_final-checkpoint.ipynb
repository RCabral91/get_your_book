# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import urllib.parse
from urllib.parse import urljoin
import csv

# %%
API_KEY = "AIzaSyAVWQOFupr20cHiAeA0cfcjEFTi-VcFiH4AIzaSyAVWQOFupr20cHiAeA0cfcjEFTi-VcFiH4"

# %%
df = pd.read_csv("/home/rafael/Área de Trabalho/CUROS IRONHACK/SEMANA 10/get_your_book/data/raw/processed/books_final_version_cleaned.csv", engine="python")
df.head(2)
# Out:
#        title            author  \
# 0  Faithless   karin slaughter
# 1      Congo  michael crichton
#
#                                          description  url         isbn13  \
# 0  The victim was buried alive in the Georgia woo...  NaN  9780440242918
# 1  Three adventurers trek into the Congo in searc...  NaN  9780060541835
#
#                                                genre  \
# 0  'Audiobook'], 'Crime', 'Fiction', 'Mystery Thr...
# 1  'Adventure', 'Classics', 'Fantasy'], 'Horror',...
#
#                                      cover_image_uri  needs_cover
# 0  https://covers.openlibrary.org/b/isbn/97804402...        False
# 1  https://covers.openlibrary.org/b/isbn/97800605...        False

# %%
# =====================================================
# 0️⃣ Imports e setup
# =====================================================
import os, joblib, numpy as np, pandas as pd
from pathlib import Path
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import normalize
from scipy.sparse import save_npz
import matplotlib.pyplot as plt

# Caminhos
DATA_PATH = Path("/home/rafael/Área de Trabalho/CUROS IRONHACK/SEMANA 10/get_your_book/data/raw/processed")
INPUT_CSV = DATA_PATH / "books_final_version_cleaned.csv"
OUTPUT_DIR = DATA_PATH / "ml_outputs"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# =====================================================
# 1️⃣ Carregar dataset limpo
# =====================================================
df = pd.read_csv(INPUT_CSV)
print("Shape:", df.shape)
print(df.columns.tolist())

# =====================================================
# 2️⃣ Criar campo de texto para NLP
# =====================================================
for col in ["title", "author", "genre", "description"]:
    df[col] = df[col].fillna("").astype(str)

df["text"] = df["title"] + ". " + df["author"] + ". " + df["genre"] + ". " + df["description"]

# =====================================================
# 3️⃣ Vetorização TF-IDF
# =====================================================
vectorizer = TfidfVectorizer(
    stop_words="english",
    ngram_range=(1, 2),
    max_df=0.9,
    min_df=3,
    max_features=20000
)
X = vectorizer.fit_transform(df["text"])
X_norm = normalize(X, norm="l2", copy=True)

print("TF-IDF shape:", X.shape)

# =====================================================
# 4️⃣ Teste de K (Silhouette)
# =====================================================
Ks = list(range(4, 13))
scores = {}

for k in Ks:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    labels = kmeans.fit_predict(X)
    score = silhouette_score(X, labels, sample_size=min(2000, X.shape[0]), random_state=42)
    scores[k] = score
    print(f"k={k}: silhouette={score:.4f}")

best_k = max(scores, key=scores.get)
print(f"\n✅ Melhor K = {best_k}  (Silhouette = {scores[best_k]:.4f})")

# Visualizar gráfico Silhouette
plt.figure(figsize=(8, 4))
plt.plot(Ks, [scores[k] for k in Ks], marker="o")
plt.title("Silhouette Score por número de clusters (KMeans)")
plt.xlabel("Número de clusters (k)")
plt.ylabel("Silhouette Score")
plt.show()

# =====================================================
# 5️⃣ Treinar modelo final
# =====================================================
kmeans_final = KMeans(n_clusters=best_k, random_state=42, n_init=10)
labels = kmeans_final.fit_predict(X)
df["cluster"] = labels

# =====================================================
# 6️⃣ Termos representativos
# =====================================================
feature_names = np.array(vectorizer.get_feature_names_out())
centers = kmeans_final.cluster_centers_
top_terms = []

for i in range(best_k):
    top_idx = centers[i].argsort()[-10:][::-1]
    top_terms.append(", ".join(feature_names[top_idx]))

cluster_df = pd.DataFrame({
    "cluster": range(best_k),
    "top_terms": top_terms
})

print("\n=== Cluster overview ===")
display(cluster_df)

# =====================================================
# 7️⃣ Salvar artefatos
# =====================================================
df_out = OUTPUT_DIR / "books_clustered.csv"
df.to_csv(df_out, index=False, encoding="utf-8")
joblib.dump(vectorizer, OUTPUT_DIR / "tfidf_vectorizer.joblib")
joblib.dump(kmeans_final, OUTPUT_DIR / "kmeans_model.joblib")
save_npz(OUTPUT_DIR / "tfidf_matrix_norm.npz", X_norm)

print(f"\n📘 Arquivos salvos em: {OUTPUT_DIR}")
# Out:
# Shape: (3347, 7)
# ['title', 'author', 'description', 'url', 'isbn13', 'cover_image_uri', 'genre']
# TF-IDF shape: (3347, 6488)
# k=4: silhouette=0.0285
# k=5: silhouette=0.0340
# k=6: silhouette=0.0362
# k=7: silhouette=0.0387
# k=8: silhouette=0.0421
# k=9: silhouette=0.0433
# k=10: silhouette=0.0336
# k=11: silhouette=0.0468
# k=12: silhouette=0.0229
#
# ✅ Melhor K = 11  (Silhouette = 0.0468)
# === Cluster overview ===
#     cluster                                          top_terms
# 0         0  new, world, life, book, history, edition, work...
# 1         1  epub digitized, book epub, proofread volunteer...
# 2         2  mystery nonfiction, art nan, occult art, nonfi...
# 3         3  fiction, fantasy, science fiction, science, ad...
# 4         4  mythology, mythology poetry, fantasy, poetry s...
# 5         5  work, important, original, scholars, united, k...
# 6         6  nonfiction, history, philosophy, philosophy na...
# 7         7  literature, fiction, nan free, classics, ficti...
# 8         8  mystery, thriller, fiction, horror, fiction my...
# 9         9  fiction, historical, fiction historical, histo...
# 10       10  century horror, plays romanticism, horror play...
# 📘 Arquivos salvos em: /home/rafael/Área de Trabalho/CUROS IRONHACK/SEMANA 10/get_your_book/data/raw/processed/ml_outputs

# %%
df["genre"].unique()
# Out:
# array(["'Audiobook'], 'Crime', 'Fiction', 'Mystery Thriller', 'Suspense', 'Thriller', Mystery;Thriller;Mystery,Crime;Fiction;Suspense;Thriller,Mystery Thriller;Audiobook;Adult;Mystery,Detective;Contemporary, ['Mystery'",
#        "'Adventure', 'Classics', 'Fantasy'], 'Horror', 'Science Fiction', 'Thriller', Fiction;Science Fiction;Thriller;Adventure;Horror;Mystery;Suspense;Cultural,Africa;Novels;Thriller,Mystery Thriller, ['Fiction'",
#        "'Contemporary', 'Historical Fiction', 'Literature', 'Novels'], 'Turkish Literature', 'Turkish', ['Fiction', nan",
#        "'Audiobook', 'Crime', 'Fiction', 'Mystery Thriller'], 'Mystery', 'Thriller', Fantasy;Fiction;Horror;Science Fiction;Adventure;Westerns;Audiobook;Science Fiction Fantasy;Thriller;Apocalyptic,Post Apocalyptic, ['Horror'",
#        "'Entrepreneurship'], 'Finance', 'Nonfiction', 'Personal Development', 'Productivity', 'Self Help', ['Business', nan",
#        "'Adult'], 'Crime', 'Fiction', 'Mystery Thriller', 'Suspense', 'Thriller', ['Mystery', nan",
#        "'Adventure', 'Fiction', 'Magic'], 'Middle Grade', 'Romance', 'Young Adult', ['Fantasy', nan",
#        "'Fantasy', 'Fiction'], 'Magic', 'Paranormal', 'Romance', 'Witches', ['Young Adult', nan",
#        "'Biography'], 'Comics', 'LGBT', 'Memoir', 'Nonfiction', 'Queer', ['Graphic Novels', nan",
#        "'Adventure', 'Classics', 'Fantasy'], 'France', 'Science Fiction', 'Travel', ['Fiction', nan",
#        "'Adult'], 'British Literature', 'Fiction', 'Historical', 'Romance', 'Tudor Period', ['Historical Fiction', nan",
#        "'Fantasy', 'Fiction', 'Mystery', 'Short Stories', 'Suspense'], 'Thriller', ['Horror', nan",
#        "'Biology', 'Nonfiction', 'Philosophy', 'Politics'], 'Science', 'Sociology', ['Psychology', nan",
#        "'Classics'], 'Essays', 'France', 'French Literature', 'Literature', 'Nonfiction', ['Philosophy', nan",
#        "'Adventure'], 'Dystopia', 'Fantasy', 'Fiction', 'Horror', 'Science Fiction', ['Young Adult', nan",
#        "'Audiobook'], 'Classics', 'Fantasy', 'Fiction', 'Science Fiction Fantasy', 'Space Opera', ['Science Fiction', nan",
#        "'Audiobook', 'Biology', 'Health', 'Medical'], 'Medicine', 'Science', ['Nonfiction', nan",
#        "'Classics'], 'Comedy', 'Fantasy', 'Fiction', 'Humor', 'Science Fiction Fantasy', ['Science Fiction', nan",
#        "'Adventure', 'Classics', 'Fiction', 'Middle Grade'], 'Mystery', 'Young Adult', ['Childrens', nan",
#        "'Business', 'Communication', 'Nonfiction', 'Personal Development', 'Psychology', 'Relationships'], ['Self Help', nan",
#        "'Adult Fiction', 'Adult', 'Audiobook'], 'Chick Lit', 'Contemporary', 'Fiction', ['Romance', nan",
#        "'Fiction', 'Historical Fiction', 'Historical', 'Medieval', 'Romance', 'Scotland'], ['Historical Romance', nan",
#        "'Fairy Tales', 'Fiction'], 'Historical Fiction', 'Retellings', 'Romance', 'Young Adult', ['Fantasy', nan",
#        "'Classics', 'Historical', 'History', 'Mystery', 'Nonfiction', 'Occult'], ['Art', nan",
#        "'Classics', 'Contemporary', 'Literary Fiction', 'Mystery Thriller'], 'Mystery', 'Thriller', ['Fiction', nan",
#        "'Biography', 'Chick Lit', 'Memoir', 'Romance', 'Spirituality'], 'Travel', ['Nonfiction', nan",
#        "'Adult'], 'Audiobook', 'Autobiography', 'Biography', 'Memoir', 'Mental Health', ['Nonfiction', nan",
#        "'American History', 'American Revolution', 'Audiobook'], 'Historical', 'Nonfiction', 'War', ['History', nan",
#        "'Fae', 'Fantasy Romance'], 'Fiction', 'New Adult', 'Romance', 'Young Adult', ['Fantasy', nan",
#        "'Adventure'], 'American', 'Fiction', 'Literature', 'Novels', 'School', ['Classics', nan",
#        "'Chick Lit', 'Contemporary', 'Fiction', 'Realistic Fiction'], 'Romance', 'Teen', ['Young Adult', nan",
#        "'Classics', 'Contemporary', 'Crime', 'Literature'], 'Novels', 'Scotland', ['Fiction', nan",
#        "'Adventure'], 'Dragons', 'Fiction', 'Science Fiction Fantasy', 'Science Fiction', 'Young Adult', ['Fantasy', nan",
#        "'Fiction', 'Horror', 'New Weird'], 'Science Fiction', 'Short Stories', 'Weird Fiction', ['Fantasy', nan",
#        "'Fantasy', 'Fiction', 'Medieval', 'Mythology'], 'Poetry', 'School', ['Classics', nan",
#        "'Christianity', 'Classics', 'Nonfiction', 'Russia', 'Spirituality'], 'Theology', ['Philosophy', nan",
#        "'Dystopia', 'Fiction'], 'Retellings', 'Science Fiction', 'Short Stories', 'Young Adult', ['Fantasy', nan",
#        "'Classics', 'Fiction', 'Literature'], 'Philosophy', 'Religion', 'Spirituality', ['Poetry', nan",
#        "'Gender Studies'], 'Gender', 'Nonfiction', 'Philosophy', 'Queer', 'Theory', ['Feminism', nan",
#        "'Audiobook', 'Mental Health', 'Personal Development', 'Psychology', 'Self Help', 'Spirituality'], ['Nonfiction', nan",
#        "'Audiobook'], 'Business', 'Personal Development', 'Productivity', 'Psychology', 'Self Help', ['Nonfiction', nan",
#        "'Fiction', 'Military Fiction', 'Science Fiction Fantasy', 'Space Opera', 'Space'], 'War', ['Science Fiction', nan",
#        "'Fantasy', 'Fiction', 'Historical Fiction', 'Supernatural'], 'Thriller', 'Vampires', ['Horror', nan",
#        "'Adult Fiction', 'Chick Lit', 'Contemporary', 'Fantasy', 'Fiction', 'Womens Fiction'], ['Romance', nan",
#        "'Audiobook'], 'Dystopia', 'Fantasy', 'Fiction', 'Romance', 'Science Fiction', ['Young Adult', nan",
#        "'British Literature', 'Feminism', 'Fiction', 'Literary Fiction'], 'Literature', 'Novels', ['Classics', nan",
#        "'Adventure', 'Childrens', 'Classics', 'Fiction', 'Magic', 'Middle Grade'], ['Fantasy', nan",
#        "'Adventure', 'Dragons', 'Fiction'], 'Magic', 'Science Fiction Fantasy', 'Urban Fantasy', ['Fantasy', nan",
#        "'Audiobook'], 'Crime', 'Detective', 'Fiction', 'Italian Literature', 'Italy', ['Mystery', nan",
#        "'Contemporary', 'High School'], 'New Adult', 'Sports Romance', 'Sports', 'Young Adult', ['Romance', nan",
#        "'Classics', 'Dystopia', 'Fantasy', 'Fiction', 'Post Apocalyptic', 'Young Adult'], ['Science Fiction', nan",
#        "'Adventure', 'Epic Fantasy'], 'Fiction', 'High Fantasy', 'Science Fiction Fantasy', 'Science Fiction', ['Fantasy', nan",
#        "'Classics', 'Fiction', 'Literature'], 'Philosophy', 'Science Fiction Fantasy', 'Short Stories', ['Science Fiction', nan",
#        "'Classics'], 'Fantasy', 'Fiction', 'Humor', 'Polish Literature', 'Short Stories', ['Science Fiction', nan",
#        "'Adult', 'Audiobook', 'Chick Lit'], 'Contemporary Romance', 'Contemporary', 'Fiction', ['Romance', nan",
#        "'19th Century', 'Classics', 'Drama', 'Fiction', 'Literature'], 'Theatre', ['Plays', nan",
#        "'German Literature', 'Germany', 'Historical Fiction', 'Historical', 'Novels', 'Travel'], ['Fiction', nan",
#        "'Inspirational'], 'Literature', 'Novels', 'Philosophy', 'Self Help', 'Short Stories', ['Fiction', nan",
#        "'Crime', 'Fiction', 'Mystery Thriller', 'Scandinavian Literature', 'Sweden'], 'Thriller', ['Mystery', nan",
#        "'Audiobook', 'Crime', 'Fiction', 'Mystery Thriller'], 'Mystery', 'Thriller', ['Horror', nan",
#        "'Classics', 'German Literature', 'History'], 'Nonfiction', 'Psychology', 'Theory', ['Philosophy', nan",
#        "'18th Century', 'Classics', 'Fantasy', 'Fiction', 'Horror', 'Literature'], ['Gothic', nan",
#        "'Adventure', 'Fiction', 'France'], 'Historical Fiction', 'Historical', 'Literature', ['Classics', nan",
#        "'Audiobook', 'Crime', 'Fiction', 'Mystery', 'Paranormal'], 'Thriller', ['Horror', nan",
#        "'Fiction', 'Literature', 'Poetry', 'Politics'], 'Short Stories', 'War', ['Classics', nan",
#        "'Africa', 'Botswana', 'Crime', 'Detective', 'Fiction', 'Mystery Thriller'], ['Mystery', nan",
#        "'Adult'], 'Fantasy', 'Paranormal Romance', 'Paranormal', 'Urban Fantasy', 'Vampires', ['Romance', nan",
#        '[], nan',
#        "'20th Century'], 'American', 'Classics', 'Literary Fiction', 'Literature', 'Novels', ['Fiction', nan",
#        "'Classics', 'Fantasy', 'Fiction', 'Humor'], 'Middle Grade', 'Young Adult', ['Childrens', nan",
#        "'Fantasy', 'Fiction', 'Paranormal', 'Supernatural'], 'Thriller', 'Vampires', ['Horror', nan",
#        "'Contemporary', 'Football', 'Mystery', 'Novels'], 'Sports', 'Thriller', ['Fiction', nan",
#        "'Adventure'], 'Childrens', 'Classics', 'Fiction', 'Finnish Literature', 'Scandinavian Literature', ['Fantasy', nan",
#        "'Classics', 'Epic'], 'Fiction', 'Literature', 'Mythology', 'Nobel Prize', ['Poetry', nan",
#        "'Adventure', 'Fantasy', 'Fiction', 'France', 'Literature'], 'Science Fiction', ['Classics', nan",
#        "'19th Century', 'Classics', 'Drama', 'Fiction', 'Scandinavian Literature'], 'Theatre', ['Plays', nan",
#        "'Adventure'], 'Childrens', 'Classics', 'Fiction', 'Finnish Literature', 'Middle Grade', ['Fantasy', nan",
#        "'Dark Fantasy', 'Fantasy', 'Fiction', 'LGBT', 'Mystery'], 'Supernatural', ['Horror', nan",
#        "'Book Club', 'Contemporary', 'Literary Fiction', 'Novels', 'Relationships'], 'Romance', ['Fiction', nan",
#        "'Drama', 'Fiction', 'Literature'], 'Mythology', 'Plays', 'School', ['Classics', nan",
#        "'Adventure', 'Classics', 'France', 'French Literature', 'Historical Fiction', 'Novels'], ['Fiction', nan",
#        "'Animals', 'Childrens', 'Fantasy', 'Fiction', 'Literature'], 'Short Stories', ['Classics', nan",
#        "'Adventure', 'Bande Dessinée', 'Childrens', 'Comic Book'], 'Fiction', 'Graphic Novels', ['Comics', nan",
#        "'Audiobook'], 'Biography Memoir', 'Business', 'History', 'Nonfiction', 'Technology', ['Biography', nan",
#        "'Biography', 'History', 'Holocaust', 'Memoir', 'War'], 'World War II', ['Nonfiction', nan",
#        "'Audiobook', 'Fiction', 'Horror', 'Science Fiction Fantasy', 'Science Fiction'], 'Urban Fantasy', ['Fantasy', nan",
#        "'Adventure', 'Asia'], 'Biography', 'History', 'Memoir', 'Travel', ['Nonfiction', nan",
#        "'Classics', 'Essays', 'France', 'French Literature'], 'History', 'Nonfiction', ['Philosophy', nan",
#        "'European History'], 'Germany', 'Nonfiction', 'Politics', 'War', 'World War II', ['History', nan",
#        "'Adventure', 'Bande Dessinée', 'Fiction', 'France', 'Graphic Novels Comics'], 'Graphic Novels', ['Comics', nan",
#        "'Academic'], 'Economics', 'Military Fiction', 'Military History', 'Nonfiction', 'War', ['History', nan",
#        "'Classics', 'Dragons'], 'Fiction', 'High Fantasy', 'Magic', 'Young Adult', ['Fantasy', nan",
#        "'Childrens', 'Classics', 'Fiction', 'Finnish Literature', 'Middle Grade', 'Scandinavian Literature'], ['Fantasy', nan",
#        "'Audiobook', 'Business'], 'Personal Development', 'Psychology', 'Science', 'Self Help', ['Nonfiction', nan",
#        "'Classics'], 'Holocaust', 'Nonfiction', 'Philosophy', 'Politics', 'Psychology', ['History', nan",
#        "'American History'], 'Military Fiction', 'Military History', 'Nonfiction', 'Politics', 'War', ['History', nan",
#        "'Biography', 'Classics'], 'Memoir', 'Philosophy', 'Psychology', 'Self Help', ['Nonfiction', nan",
#        "'Contemporary'], 'Crime', 'Fiction', 'Mystery Thriller', 'Thriller', 'Young Adult', ['Mystery', nan",
#        "'Audiobook', 'Biography', 'Humor', 'Memoir', 'Nonfiction', 'Travelogue'], ['Travel', nan",
#        "'Adventure', 'Audiobook'], 'Fiction', 'Historical', 'Novels', 'Travel', ['Historical Fiction', nan",
#        "'Nonfiction', 'Philosophy', 'Psychology', 'Religion'], 'Self Help', 'Spirituality', ['Buddhism', nan",
#        "'Classics', 'Drama', 'Fiction', 'Romance', 'School', 'Theatre'], ['Plays', nan",
#        "'Classics', 'Fantasy', 'Gothic', 'Literature'], 'Mystery', 'Science Fiction', ['Horror', nan",
#        "'Crime', 'Fiction', 'Mystery Thriller', 'Romance'], 'Suspense', 'Thriller', ['Mystery', nan",
#        "'Crime', 'Fiction', 'Horror', 'Mystery Thriller', 'Suspense'], 'Thriller', ['Mystery', nan",
#        "'Biography Memoir', 'British Literature'], 'History', 'Literary Criticism', 'Literature', 'Nonfiction', ['Biography', nan",
#        "'Fiction', 'Literature', 'Plays', 'Read For School'], 'School', 'Theatre', ['Classics', nan",
#        "'Ancient History'], 'Ancient', 'Classics', 'History', 'Nonfiction', 'School', ['Philosophy', nan",
#        "'Fantasy', 'Fiction', 'Mystery', 'Paranormal', 'Thriller'], 'Young Adult', ['Horror', nan",
#        "'Classics', 'Literature'], 'Magical Realism', 'Poland', 'Polish Literature', 'Short Stories', ['Fiction', nan",
#        "'Canada', 'Canadian Literature', 'Classics', 'Contemporary', 'Feminism'], 'Literary Fiction', ['Fiction', nan",
#        "'Drama', 'Fiction', 'German Literature', 'Literature'], 'Plays', 'Poetry', ['Classics', nan",
#        "'18th Century'], 'Adventure', 'Classics', 'Fantasy', 'Literature', 'Novels', ['Fiction', nan",
#        "'Audiobook', 'Historical'], 'Military Fiction', 'Nonfiction', 'War', 'World War II', ['History', nan",
#        "'Fantasy', 'Fiction', 'Gothic'], 'Horror', 'Humor', 'Short Stories', ['Classics', nan",
#        "'Ancient History', 'Classics', 'Greece'], 'Nonfiction', 'Politics', 'War', ['History', nan",
#        "'Adventure'], 'Classics', 'Fiction', 'Humor', 'Romance', 'Young Adult', ['Fantasy', nan",
#        "'Adventure', 'Cyberpunk', 'Fiction', 'Science Fiction Fantasy', 'Science Fiction', 'Speculative Fiction'], ['Fantasy', nan",
#        "'Fantasy', 'Fiction', 'Paranormal'], 'Supernatural', 'Thriller', 'Werewolves', ['Horror', nan",
#        "'Classics', 'Drama', 'Fantasy', 'Fiction', 'School', 'Theatre'], ['Plays', nan",
#        "'Contemporary Romance', 'Contemporary', 'Erotica', 'New Adult'], 'Sports Romance', 'Sports', ['Romance', nan",
#        "'Business', 'Classics', 'History', 'Military Fiction'], 'Philosophy', 'War', ['Nonfiction', nan",
#        "'Adult', 'Contemporary Romance', 'Contemporary', 'Erotica'], 'Music', 'New Adult', ['Romance', nan",
#        "'British Literature'], 'Chick Lit', 'Drama', 'Historical Fiction', 'Historical', 'Romance', ['Fiction', nan",
#        "'Chick Lit', 'Contemporary'], 'Historical Fiction', 'Ireland', 'Irish Literature', 'Romance', ['Fiction', nan",
#        "'Adventure', 'Fantasy'], 'Historical Fiction', 'Historical', 'Pirates', 'Thriller', ['Fiction', nan",
#        "'Drama'], 'Fiction', 'Historical Fiction', 'Literature', 'Novels', 'Romance', ['Classics', nan",
#        "'Classics', 'Fantasy', 'Fiction', 'Literature'], 'Mythology', 'School', ['Poetry', nan",
#        "'Business', 'Leadership'], 'Nonfiction', 'Personal Development', 'Science', 'Self Help', ['Psychology', nan",
#        "'Classics'], 'Historical Fiction', 'Literature', 'Novels', 'Russia', 'Russian Literature', ['Fiction', nan",
#        "'Adult'], 'Contemporary Romance', 'Contemporary', 'Humor', 'Music', 'New Adult', ['Romance', nan",
#        "'Fiction', 'Historical Fiction', 'Historical Romance', 'Historical', 'Love Story'], 'Romantic', ['Romance', nan",
#        "'British Literature', 'Historical Fiction', 'Historical', 'Romance', 'War'], 'World War II', ['Fiction', nan",
#        "'Fantasy', 'Mythology'], 'Paranormal', 'Romance', 'Urban Fantasy', 'Vampires', ['Paranormal Romance', nan",
#        "'Audiobook'], 'Classics', 'Crime', 'Detective', 'Fiction', 'Mystery Thriller', ['Mystery', nan",
#        "'Adventure', 'Childrens', 'Fiction', 'Magic'], 'Middle Grade', 'Young Adult', ['Fantasy', nan",
#        "'Fiction'], 'Historical Fiction', 'Historical', 'Regency Romance', 'Regency', 'Romance', ['Historical Romance', nan",
#        "'Biography', 'Crime', 'Historical'], 'History', 'Mystery', 'True Crime', ['Nonfiction', nan",
#        "'Apocalyptic'], 'Audiobook', 'Dystopia', 'Fantasy', 'Fiction', 'Post Apocalyptic', ['Science Fiction', nan",
#        "'Anthologies'], 'Fantasy', 'Fiction', 'Historical Fiction', 'Magical Realism', 'Science Fiction', ['Short Stories', nan",
#        "'Adult Fiction', 'Chick Lit', 'Contemporary Romance', 'Contemporary', 'Fiction', 'Womens Fiction'], ['Romance', nan",
#        "'Asia'], 'Classics', 'Historical Fiction', 'Japan', 'Japanese Literature', 'Literature', ['Fiction', nan",
#        "'Biography'], 'Classics', 'Literature', 'Memoir', 'Nature', 'Nonfiction', ['Philosophy', nan",
#        "'Classics', 'Mathematics', 'Nonfiction', 'Philosophy', 'Physics', 'Popular Science'], ['Science', nan",
#        "'College'], 'Contemporary Romance', 'Contemporary', 'New Adult', 'Novella', 'Young Adult', ['Romance', nan",
#        "'Adventure', 'Fantasy', 'Fiction', 'Historical', 'Medieval', 'War'], ['Historical Fiction', nan",
#        "'18th Century'], 'Classics', 'German Literature', 'Metaphysics', 'Nonfiction', 'Science', ['Philosophy', nan",
#        "'Classics'], 'History', 'Nonfiction', 'Politics', 'Religion', 'Theology', ['Philosophy', nan",
#        "'Audiobook', 'Personal Development', 'Philosophy', 'Psychology', 'Self Help', 'Unfinished'], ['Nonfiction', nan",
#        "'Audiobook', 'Crime', 'Fiction', 'Mystery Thriller'], 'Scotland', 'Thriller', ['Mystery', nan",
#        "'Adult'], 'Fiction', 'Historical Fiction', 'Historical', 'Regency', 'Romance', ['Historical Romance', nan",
#        "'Classics', 'History', 'Nonfiction', 'Political Science', 'Politics', 'School'], ['Philosophy', nan",
#        "'Audiobook', 'Fiction', 'High Fantasy'], 'Romance', 'Young Adult Fantasy', 'Young Adult', ['Fantasy', nan",
#        "'Classics', 'Fiction', 'Mystery', 'Novels'], 'Robots', 'Science Fiction Fantasy', ['Science Fiction', nan",
#        "'Audiobook'], 'Fantasy', 'Fiction', 'Science Fiction Fantasy', 'Science Fiction', 'Speculative Fiction', ['Short Stories', nan",
#        "'Fiction', 'Horror', 'Paranormal', 'Supernatural'], 'Vampires', 'Young Adult', ['Fantasy', nan",
#        "'Action'], 'Adventure', 'Fiction', 'Mythology', 'Teen', 'Young Adult', ['Fantasy', nan",
#        "'Asian Literature'], 'Classics', 'Japan', 'Japanese Literature', 'Literature', 'Novels', ['Fiction', nan",
#        "'Adult', 'Adventure', 'Audiobook', 'Fiction', 'Space', 'Thriller'], ['Science Fiction', nan",
#        "'Audiobook', 'Fiction', 'Science Fiction Fantasy', 'Space Opera', 'Space', 'Speculative Fiction'], ['Science Fiction', nan",
#        "'Audiobook', 'Crime', 'Horror', 'Mystery Thriller'], 'Mystery', 'Thriller', ['Fiction', nan",
#        "'Adventure', 'Fiction', 'Historical Fiction', 'Literature'], 'Scotland', 'Young Adult', ['Classics', nan",
#        "'Classics', 'Fantasy', 'Fiction', 'Gothic'], 'Literature', 'School', ['Poetry', nan",
#        "'Essays', 'France', 'Mythology', 'Nonfiction', 'Sociology'], 'Theory', ['Philosophy', nan",
#        "'Animals', 'Cats', 'Chapter Books'], 'Childrens', 'Fiction', 'Middle Grade', ['Fantasy', nan",
#        "'Classics'], 'Collections', 'Fantasy', 'Fiction', 'Horror', 'Short Stories', ['Science Fiction', nan",
#        "'Business'], 'Classics', 'History', 'Nonfiction', 'Philosophy', 'Politics', ['Economics', nan",
#        "'Drama', 'Fiction', 'Historical Fiction', 'Literature'], 'Plays', 'Theatre', ['Classics', nan",
#        "'Biology', 'Classics', 'Evolution', 'History'], 'Nonfiction', 'Philosophy', ['Science', nan",
#        "'Love', 'Philosophy', 'Psychology', 'Relationships', 'Romance', 'Self Help'], ['Fiction', nan",
#        "'Audiobook', 'Classics'], 'Crime', 'Detective', 'Fiction', 'Mystery Thriller', ['Mystery', nan",
#        "'Classics', 'France', 'French Literature', 'Humor'], 'Literature', 'Philosophy', ['Fiction', nan",
#        "'Action', 'Adventure', 'Espionage', 'Military Fiction', 'Suspense'], 'Thriller', ['Fiction', nan",
#        "'Classics', 'Dystopia', 'Fiction', 'Horror', 'Novels', 'Science Fiction Fantasy'], ['Science Fiction', nan",
#        "'Classics', 'Drama', 'Fiction', 'Mythology', 'Theatre', 'Tragedy'], ['Plays', nan",
#        "'Classics', 'Drama', 'Feminism'], 'Fiction', 'School', 'Theatre', ['Plays', nan",
#        "'Finance', 'Money', 'Nonfiction', 'Personal Development', 'Psychology'], 'Self Help', ['Business', nan",
#        "'18th Century'], 'Art', 'British Literature', 'Fiction', 'Greece', 'Historical', ['Historical Fiction', nan",
#        "'Adventure', 'Audiobook'], 'Classics', 'Dinosaurs', 'Fantasy', 'Fiction', ['Science Fiction', nan",
#        "'Drama', 'Fiction', 'Humor', 'Literature', 'Plays', 'Theatre'], ['Classics', nan",
#        "'Fiction', 'Horror', 'Novels'], 'Occult', 'Science Fiction', 'Speculative Fiction', ['Fantasy', nan",
#        "'Classics', 'Drama'], 'German Literature', 'Literature', 'Plays', 'Poetry', ['Fiction', nan",
#        "'20th Century'], 'Classics', 'France', 'Nonfiction', 'Psychology', 'Theory', ['Philosophy', nan",
#        "'Contemporary', 'Fiction', 'High School'], 'Mental Health', 'Realistic Fiction', 'Teen', ['Young Adult', nan",
#        "'Adult Fiction'], 'Chick Lit', 'Contemporary', 'Ireland', 'Irish Literature', 'Romance', ['Fiction', nan",
#        "'Classics', 'Fantasy', 'Fiction', 'Novels'], 'Science Fiction Fantasy', 'Space Opera', ['Science Fiction', nan",
#        "'Audiobook'], 'Chick Lit', 'Contemporary', 'Fiction', 'France', 'Novels', ['Romance', nan",
#        "'Classics', 'Essays', 'Feminism', 'Literature'], 'Philosophy', 'Politics', ['Nonfiction', nan",
#        "'Dark Fantasy', 'Fiction', 'Horror', 'Novels'], 'Science Fiction Fantasy', 'Science Fiction', ['Fantasy', nan",
#        "'Fiction', 'Historical Fiction', 'Historical', 'Literature', 'Novels', 'School'], ['Classics', nan",
#        "'18th Century', 'British Literature', 'Fiction', 'Historical Fiction', 'Literature', 'Novels'], ['Classics', nan",
#        "'Audiobook', 'Chick Lit', 'Contemporary', 'Drama'], 'Family', 'Fiction', ['Romance', nan",
#        "'Audiobook', 'Historical Fiction', 'Historical Romance'], 'Historical', 'Literature', 'Novels', ['Fiction', nan",
#        "'College', 'Contemporary Romance'], 'Contemporary', 'New Adult', 'Sports Romance', 'Sports', ['Romance', nan",
#        "'Adult'], 'Audiobook', 'Chick Lit', 'Contemporary', 'Historical Fiction', 'Romance', ['Fiction', nan",
#        "'Fiction', 'Historical Fiction', 'Literature'], 'Romance', 'Russia', 'Russian Literature', ['Classics', nan",
#        "'20th Century', 'Feminism', 'Fiction', 'Literary Fiction'], 'Literature', 'Novels', ['Classics', nan",
#        "'Animals', 'Childrens', 'Fantasy', 'Fiction', 'Middle Grade'], 'Young Adult', ['Classics', nan",
#        "'Fantasy', 'Fiction', 'Gothic', 'Literature'], 'School', 'Science Fiction', ['Horror', nan",
#        "'Audiobook', 'Contemporary'], 'Fiction', 'Historical', 'Mystery', 'Romance', ['Historical Fiction', nan",
#        "'Fiction', 'Historical Fiction'], 'Literature', 'Poetry', 'School', 'Short Stories', ['Classics', nan",
#        "'19th Century', 'British Literature'], 'Fiction', 'Historical Fiction', 'Literature', 'Victorian', ['Classics', nan",
#        "'18th Century', 'British Literature'], 'Historical', 'History', 'Literature', 'Nonfiction', ['Classics', nan",
#        "'Ancient History', 'Ancient', 'Biography', 'Classics', 'Historical'], 'Nonfiction', ['History', nan",
#        "'Fiction', 'Historical', 'Literature'], 'Mystery', 'Romance', 'Russia', ['Historical Fiction', nan",
#        "'19th Century', 'Fiction', 'Gothic', 'Literature'], 'Romance', 'Victorian', ['Classics', nan",
#        "'Adventure', 'Childrens', 'Classics', 'Fantasy', 'Fiction', 'Young Adult'], ['Picture Books', nan",
#        "'Adventure'], 'Childrens', 'Classics', 'Fiction', 'Middle Grade', 'Young Adult', ['Fantasy', nan",
#        "'British Literature', 'Crime', 'Fiction', 'Mystery Thriller', 'Suspense'], 'Thriller', ['Mystery', nan",
#        "'Fiction', 'Ghost Stories', 'Ghosts', 'Gothic', 'Mystery'], 'Paranormal', ['Horror', nan",
#        "'Fantasy'], 'Fiction', 'Literature', 'Mythology', 'Poetry', 'School', ['Classics', nan",
#        "'British Literature'], 'Gothic', 'Horror', 'Literature', 'Mystery', 'Novels', ['Classics', nan",
#        "'Dystopia', 'Fiction', 'Literature', 'Philosophy', 'Politics', 'School'], ['Classics', nan",
#        "'Fiction', 'Japan', 'Japanese Literature', 'Mystery', 'Paranormal'], 'Thriller', ['Horror', nan",
#        "'Adult', 'Audiobook'], 'Chick Lit', 'Contemporary Romance', 'Contemporary', 'Fiction', ['Romance', nan",
#        "'19th Century'], 'Fiction', 'Literature', 'Novels', 'Russia', 'Russian Literature', ['Classics', nan",
#        "'Business'], 'Classics', 'History', 'Japan', 'Martial Arts', 'Nonfiction', ['Philosophy', nan",
#        "'19th Century', 'Fiction', 'France', 'French Literature', 'Historical Fiction'], 'Literature', ['Classics', nan",
#        "'Audiobook'], 'Fiction', 'Historical Fiction', 'Historical', 'Middle Grade', 'Young Adult', ['Mystery', nan",
#        "'Fantasy', 'Fiction', 'Literature'], 'Plays', 'School', 'Theatre', ['Classics', nan",
#        "'Classics'], 'Dystopia', 'Fantasy', 'Fiction', 'Middle Grade', 'Science Fiction', ['Young Adult', nan",
#        "'Classics', 'German Literature', 'Germany', 'Literature', 'Novels'], 'Romance', ['Fiction', nan",
#        "'19th Century'], 'Childrens', 'Fairy Tales', 'Fantasy', 'Fiction', 'Short Stories', ['Classics', nan",
#        "'Ancient'], 'Classics', 'History', 'Nonfiction', 'Political Science', 'Politics', ['Philosophy', nan",
#        "'Classics', 'Crime', 'Detective'], 'Fiction', 'Horror', 'Short Stories', ['Mystery', nan",
#        "'Classics', 'History', 'Personal Development', 'Psychology', 'Self Help', 'Spirituality'], ['Nonfiction', nan",
#        "'Fiction', 'Gothic', 'Historical Fiction'], 'Horror', 'Mystery', 'Romance', ['Classics', nan",
#        "'Adventure'], 'Childrens', 'Fantasy', 'Fiction', 'Italian Literature', 'Italy', ['Classics', nan",
#        "'Fiction', 'Gothic', 'Historical Fiction', 'Historical Romance', 'Historical'], 'Mystery', ['Romance', nan",
#        "'Drama', 'Fiction', 'Literature'], 'Plays', 'Read For School', 'School', ['Classics', nan",
#        "'Drama', 'Fiction', 'Literature', 'Plays', 'Poetry', 'Reference'], ['Classics', nan",
#        "'Childrens', 'Classics', 'Historical Fiction', 'Historical', 'Literature'], 'Young Adult', ['Fiction', nan",
#        "'19th Century', 'Horror'], 'Plays', 'Romanticism', ['Classics', nan",
#        "'Christian', 'Christianity', 'Classics', 'History'], 'Nonfiction', 'Philosophy', ['Religion', nan",
#        "'Fiction', 'Gay'], 'LGBT', 'Literary Fiction', 'Queer', 'Romance', ['Classics', nan",
#        "'20th Century', 'American', 'Classics', 'Historical Fiction'], 'Literature', 'Novels', ['Fiction', nan",
#        "'Classics', 'Fiction'], 'LGBT', 'Lesbian', 'Mythology', 'Queer', ['Poetry', nan",
#        "'Classics'], 'Fantasy', 'Fiction', 'Japan', 'Japanese Literature', 'Short Stories', ['Horror', nan",
#        "'Adventure', 'Animals', 'Classics', 'Historical Fiction', 'Literature'], 'Young Adult', ['Fiction', nan",
#        "'American', 'Classics', 'Fantasy', 'Novels'], 'Science Fiction', 'The United States Of America', ['Fiction', nan",
#        "'19th Century'], 'Brazil', 'Fiction', 'Literature', 'Portuguese Literature', 'Romance', ['Classics', nan",
#        "'Animals', 'Cats', 'Classics', 'Fantasy'], 'Fiction', 'Picture Books', ['Childrens', nan",
#        "'Adventure', 'Classics', 'Crime', 'Espionage'], 'Mystery', 'Thriller', ['Fiction', nan",
#        "'Fiction', 'France', 'Historical Fiction', 'Historical', 'Literature', 'Novels'], ['Classics', nan",
#        "'Classics', 'Economics', 'History', 'Nonfiction', 'Political Science', 'Politics'], ['Philosophy', nan",
#        "'Adventure', 'Classics', 'Espionage'], 'Historical Fiction', 'Mystery', 'Thriller', ['Fiction', nan",
#        "'Dystopia', 'Fiction', 'Gothic'], 'Horror', 'Post Apocalyptic', 'Science Fiction', ['Classics', nan",
#        "'19th Century', 'Classics', 'France', 'French Literature', 'Literature', 'Novels'], ['Fiction', nan",
#        "'Classics', 'German Literature', 'Germany', 'Literature', 'Music', 'Novels'], ['Fiction', nan",
#        "'Adventure', 'Fantasy', 'Fiction', 'Historical Fiction', 'Novels'], 'Romance', ['Classics', nan",
#        "'Classics', 'German Literature', 'Literature', 'Novels', 'Philosophy', 'Science Fiction'], ['Fiction', nan",
#        "'Childrens', 'Classics', 'Family'], 'Historical Fiction', 'Kids', 'Young Adult', ['Fiction', nan",
#        "'19th Century', 'Fiction', 'France', 'French Literature', 'Novels'], 'Roman', ['Classics', nan",
#        "'20th Century', 'Books About Books'], 'British Literature', 'Classics', 'Literary Fiction', 'Novels', ['Fiction', nan",
#        "'Adventure', 'Animals', 'Fantasy', 'Fiction', 'Literature'], 'Romance', ['Classics', nan",
#        "'Drama', 'Fiction', 'Literature'], 'Plays', 'Romance', 'School', ['Classics', nan",
#        "'Adventure'], 'Alternate History', 'Dinosaurs', 'Fantasy', 'Fiction', 'Science Fiction Fantasy', ['Science Fiction', nan",
#        "'Business', 'Classics'], 'Finance', 'Nonfiction', 'Philosophy', 'Politics', ['Economics', nan",
#        "'19th Century', 'British Literature'], 'Classics', 'Fiction', 'Literature', 'Romanticism', ['Poetry', nan",
#        "'Christmas', 'Classics', 'Crime', 'Detective'], 'Fiction', 'Mystery Thriller', ['Mystery', nan",
#        "'19th Century', 'Fantasy', 'Fiction', 'Gothic', 'Horror', 'Religion'], ['Classics', nan",
#        "'Ancient'], 'Classics', 'History', 'Nonfiction', 'Politics', 'School', ['Philosophy', nan",
#        "'Classics', 'Fantasy', 'Fiction', 'Mystery', 'Paranormal', 'Pulp'], ['Horror', nan",
#        "'Adventure', 'Classics', 'Historical Fiction', 'Literature', 'School'], 'Young Adult', ['Fiction', nan",
#        "'Classics', 'Essays', 'Nonfiction', 'Religion'], 'Science', 'Sociology', ['Philosophy', nan",
#        "'18th Century'], 'American', 'Fiction', 'Gothic', 'Horror', 'Literature', ['Classics', nan",
#        "'Chapter Books'], 'Classics', 'Fiction', 'Middle Grade', 'Mystery', 'Young Adult', ['Childrens', nan",
#        "'American'], 'Classics', 'Historical Fiction', 'Literature', 'Novels', 'Religion', ['Fiction', nan",
#        "'Adventure', 'Childrens', 'Fiction', 'Historical Fiction', 'Literature', 'Young Adult'], ['Classics', nan",
#        "'Adventure', 'Classics', 'Fantasy', 'Fiction', 'France', 'Literature'], ['Science Fiction', nan",
#        "'Adventure', 'Africa', 'Fantasy', 'Fiction', 'Pulp', 'Science Fiction'], ['Classics', nan",
#        "'18th Century'], 'Essays', 'Fiction', 'Humor', 'Literature', 'Philosophy', ['Classics', nan",
#        "'Crime', 'Fiction', 'Horror', 'Mystery', 'Paranormal'], 'Thriller', ['Fantasy', nan",
#        "'Audiobook'], 'Fantasy', 'Fiction', 'Gothic', 'Horror', 'Short Stories', ['Classics', nan",
#        "'Economics', 'History', 'Nonfiction', 'Politics', 'Sociology', 'Theory'], ['Philosophy', nan",
#        "'Drama'], 'Fiction', 'Literature', 'Plays', 'Poetry', 'Short Stories', ['Classics', nan",
#        "'Ancient History', 'Classics', 'Historical', 'Nonfiction', 'Politics', 'World History'], ['History', nan",
#        "'Classics', 'Czech Literature'], 'German Literature', 'Literature', 'Novels', 'Philosophy', ['Fiction', nan",
#        '',
#        "'Ancient'], 'Fantasy', 'Fiction', 'Literature', 'Mythology', 'Poetry', ['Classics', nan",
#        "'Fantasy'], 'Fiction', 'Literature', 'Philosophy', 'Poetry', 'Religion', ['Classics', nan",
#        "'Classics'], 'Nonfiction', 'Philosophy', 'Psychoanalysis', 'Religion', 'Science', ['Psychology', nan",
#        "'Classics', 'Fiction', 'Literature', 'Romance', 'School'], 'Theatre', ['Plays', nan",
#        "'American History'], 'Autobiography', 'Classics', 'History', 'Memoir', 'Nonfiction', ['Biography', nan",
#        "'Fantasy', 'Fiction', 'Literature'], 'Poetry', 'Romance', 'School', ['Plays', nan",
#        "'19th Century', 'British Literature'], 'Fiction', 'Historical Fiction', 'Literature', 'Romance', ['Classics', nan",
#        "'Classics', 'Fiction', 'Gothic'], 'Mystery Thriller', 'Novels', 'Thriller', ['Mystery', nan",
#        "'History', 'Philosophy'], 'Russia', ['Nonfiction', nan",
#        "'Biography', 'Classics', 'France', 'Literature'], 'Memoir', 'Travel', ['Nonfiction', nan",
#        "'20th Century', 'American', 'Classics', 'College'], 'School', 'The United States Of America', ['Poetry', nan",
#        "'Classics', 'Fiction', 'India', 'Indian Literature', 'Literature'], 'Philosophy', ['Poetry', nan",
#        "'Audiobook', 'Christmas', 'Classics', 'Fantasy', 'Historical Fiction'], 'Literature', ['Fiction', nan",
#        "'Ancient'], 'Classics', 'History', 'Nonfiction', 'Politics', 'Reference', ['Philosophy', nan",
#        "'Classics'], 'Fantasy', 'Fiction', 'Mystery', 'Short Stories', 'Weird Fiction', ['Horror', nan",
#        "'Classics', 'German Literature', 'Germany', 'LGBT'], 'Literature', 'Novels', ['Fiction', nan",
#        "'Essays', 'Literature'], 'Nature', 'Nonfiction', 'Philosophy', 'Politics', ['Classics', nan",
#        "'Classics', 'German Literature', 'History', 'Metaphysics'], 'Nonfiction', 'Theory', ['Philosophy', nan",
#        "'Christianity', 'Classics', 'History', 'Nonfiction'], 'Reference', 'Theology', ['Religion', nan",
#        "'Adventure', 'American'], 'Fiction', 'Historical Fiction', 'Literature', 'Novels', ['Classics', nan",
#        "'Fiction', 'Historical Fiction', 'Italian Literature', 'Italy', 'Literature', 'Romance'], ['Classics', nan",
#        "'Fiction', 'Historical Fiction', 'Literature'], 'Short Stories', 'Spain', 'Travel', ['Classics', nan",
#        "'Arthurian', 'Classics', 'Fiction', 'Historical Fiction', 'Historical'], 'Mythology', ['Fantasy', nan",
#        "'Adventure', 'Animals'], 'Childrens', 'Fantasy', 'Fiction', 'Short Stories', ['Classics', nan",
#        "'Chapter Books'], 'Childrens', 'Classics', 'Dragons', 'Fiction', 'Middle Grade', ['Fantasy', nan",
#        "'19th Century', 'Classics', 'France', 'French Literature', 'Literature', 'Romance'], ['Fiction', nan",
#        "'Fiction', 'France', 'French Literature', 'Historical Fiction', 'Literature', 'Novels'], ['Classics', nan",
#        "'Animals', 'Classics', 'Fantasy', 'Fiction', 'Picture Books', 'Short Stories'], ['Childrens', nan",
#        "'18th Century', 'Classics', 'Nonfiction', 'Psychology', 'School'], 'Science', ['Philosophy', nan",
#        "'Classics', 'History'], 'Mathematics', 'Nonfiction', 'Philosophy', 'Physics', ['Science', nan",
#        "'Classics', 'Literature', 'Politics', 'Science Fiction', 'Time Travel'], 'Utopia', ['Fiction', nan",
#        "'Classics', 'High School', 'Historical Fiction', 'Historical'], 'Literature', 'School', ['Fiction', nan",
#        "'Chick Lit', 'Contemporary', 'Drama'], 'Fiction', 'Historical Fiction', 'Historical', ['Romance', nan",
#        "'Fiction'], 'Paranormal', 'Romance', 'Urban Fantasy', 'Vampires', 'Young Adult', ['Fantasy', nan",
#        'Romance;Romance,Contemporary Romance;Contemporary;Category Romance,Harlequin;Fiction;War,Military Fiction;Womens Fiction,Chick Lit;Romance,Romantic Suspense;Romance,Category Romance;Adult, nan',
#        "'Adventure', 'Childrens', 'Fantasy', 'Fiction', 'Nobel Prize'], 'Swedish Literature', ['Classics', nan",
#        "'Antisemitism'], 'Historical', 'History', 'Nonfiction', 'Philosophy', 'Religion', ['Politics', nan",
#        'Philosophy;Psychology;Nonfiction;History;Sociology;Religion;Politics;Religion,Theology;Philosophy,Theory;Academic, nan',
#        "'Childrens', 'Classics', 'Fiction', 'Historical Fiction', 'Middle Grade', 'Young Adult'], ['Fantasy', nan",
#        "'Fantasy', 'Fiction', 'Gothic', 'Horror', 'Literature', 'Novels'], ['Classics', nan",
#        "'20th Century'], 'British Literature', 'Fiction', 'Historical Fiction', 'Literature', 'Novels', ['Classics', nan",
#        "'Classics', 'Contemporary', 'German Literature', 'Literature', 'New York'], 'Novels', ['Fiction', nan",
#        "'Ancient History', 'Ancient'], 'Biography', 'Classics', 'Nonfiction', 'Philosophy', ['History', nan",
#        "'19th Century', 'Fiction', 'Gothic', 'Historical Fiction', 'Historical'], 'Literature', ['Classics', nan",
#        "'Classics', 'Drama', 'Fiction', 'Historical Fiction', 'Read For School'], 'School', ['Plays', nan",
#        "'British Literature', 'Classics', 'Historical Fiction', 'Historical'], 'Literature', 'Romance', ['Fiction', nan",
#        "'Classics', 'Fiction', 'France', 'French Literature'], 'Gothic', 'Short Stories', ['Horror', nan",
#        "'Classics', 'France', 'French Literature', 'Literature', 'Novels'], 'Philosophy', ['Fiction', nan",
#        "'18th Century', 'British Literature'], 'Fiction', 'Gothic', 'Literature', 'Mystery', ['Classics', nan",
#        "'Childrens', 'Fiction', 'Historical Fiction', 'Historical'], 'Middle Grade', 'Young Adult', ['Classics', nan",
#        "'Childrens'], 'Fiction', 'Historical Fiction', 'Historical', 'Romance', 'Young Adult', ['Classics', nan",
#        "'Fiction', 'Literature'], 'Novels', 'Philosophy', 'Spain', 'Spanish Literature', ['Classics', nan",
#        "'Adventure', 'Classics', 'Espionage', 'Historical Fiction', 'Mystery', 'Thriller'], ['Fiction', nan",
#        "'Christian Fiction', 'Christian', 'Christianity', 'Classics', 'Religion', 'Theology'], ['Fiction', nan",
#        "'19th Century', 'American', 'Fiction', 'Historical Fiction', 'Literature', 'School'], ['Classics', nan",
#        "'Adventure', 'American', 'Canada', 'Classics', 'Fiction', 'Westerns'], ['Short Stories', nan",
#        "'20th Century', 'American', 'Classics', 'Fiction', 'Literature', 'The United States Of America'], ['Poetry', nan",
#        "'19th Century', 'Fiction', 'Historical Fiction', 'Literature', 'Novels'], 'Victorian', ['Classics', nan",
#        "'20th Century', 'British Literature', 'Fiction', 'Historical Fiction', 'Literature'], 'Novels', ['Classics', nan",
#        "'19th Century', 'Fiction', 'Historical Fiction', 'Literature', 'Romance', 'Victorian'], ['Classics', nan",
#        "'20th Century'], 'American', 'Classics', 'Literary Fiction', 'Literature', 'Short Stories', ['Fiction', nan",
#        "'Classics', 'Drama', 'Feminism'], 'Fiction', 'Humor', 'Theatre', ['Plays', nan",
#        "'19th Century', 'Audiobook', 'Classic Literature'], 'Historical Fiction', 'Historical', 'Literature', ['Fiction', nan",
#        "'Adventure', 'Fiction'], 'Young Adult', ['Historical Fiction', nan",
#        "'19th Century', 'American', 'Classics', 'Feminism'], 'Fiction', 'Literature', ['Poetry', nan",
#        "'20th Century'], 'Classics', 'German Literature', 'Germany', 'Literature', 'Short Stories', ['Fiction', nan",
#        "'Adventure', 'Childrens', 'Fiction', 'Historical Fiction', 'Literature'], 'Young Adult', ['Classics', nan",
#        "'Civil War', 'Fiction', 'Historical Fiction', 'Historical'], 'Literature', 'War', ['Classics', nan",
#        "'Childrens'], 'Historical Fiction', 'Historical', 'Literature', 'Romance', 'Young Adult', ['Fiction', nan",
#        "'Animals', 'Childrens', 'Fantasy', 'Fiction', 'Nature'], 'Young Adult', ['Classics', nan",
#        "'Catholic', 'Christian', 'Faith'], 'Nonfiction', 'Reference', 'Theology', ['Religion', nan",
#        "'Classics', 'Fiction', 'Historical', 'Poland', 'Polish Literature', 'War'], ['Historical Fiction', nan",
#        "'19th Century'], 'Adventure', 'American', 'Fiction', 'Literature', 'Short Stories', ['Classics', nan",
#        "'20th Century'], 'American', 'Fiction', 'Historical Fiction', 'Literature', 'Novels', ['Classics', nan",
#        "'Fiction', 'France', 'French Literature', 'Gothic'], 'Historical Fiction', 'Literature', ['Classics', nan",
#        "'Classics', 'Drama', 'Fiction', 'Literature'], 'Poetry', 'Theatre', ['Plays', nan",
#        "'Classics', 'History', 'Nonfiction', 'Philosophy', 'Politics', 'Womens'], ['Feminism', nan",
#        "'Christianity', 'Classics', 'Nonfiction'], 'Reference', 'Spirituality', 'Theology', ['Religion', nan",
#        "'Africa', 'Classics', 'Historical Fiction', 'Literature', 'Novels'], 'School', ['Fiction', nan",
#        "'Animals'], 'Childrens', 'Fantasy', 'Fiction', 'Picture Books', 'Short Stories', ['Classics', nan",
#        "'19th Century'], 'Classics', 'Fiction', 'France', 'French Literature', 'Literature', ['Poetry', nan",
#        "'Adventure', 'Cats', 'Fantasy', 'Fiction', 'Science Fiction Fantasy', 'Young Adult'], ['Science Fiction', nan",
#        "'19th Century', 'Classics', 'Historical Fiction', 'Literature', 'Novels'], 'Romance', ['Fiction', nan",
#        "'Classics', 'German Literature', 'Metaphysics', 'Nonfiction', 'Read For School'], 'School', ['Philosophy', nan",
#        "'19th Century'], 'Classics', 'Fiction', 'French Literature', 'Literature', 'Poetry', ['France', nan",
#        'Fantasy;Fiction;Young Adult;Childrens;Fantasy,Magic;Science Fiction Fantasy;Novels;Childrens,Middle Grade;European Literature,British Literature;Reference, nan',
#        "'American', 'Banned Books'], 'Fiction', 'Historical Fiction', 'Literature', 'Novels', ['Classics', nan",
#        "'19th Century', 'American', 'Fiction', 'Historical Fiction', 'Literature', 'Romance'], ['Classics', nan",
#        "'Adventure', 'Childrens'], 'Fiction', 'Historical Fiction', 'Literature', 'Young Adult', ['Classics', nan",
#        "'Catholic'], 'Fiction', 'France', 'Historical Fiction', 'Historical', 'Literature', ['Classics', nan",
#        "'Fantasy'], 'Fiction', 'Italian Literature', 'Literature', 'Poetry', 'Religion', ['Classics', nan",
#        "'Fiction', 'Gothic', 'Horror', 'Music', 'Mystery', 'Victorian'], ['Classics', nan",
#        "'Classics', 'Nonfiction', 'Personal Development', 'Philosophy', 'Psychology', 'Spirituality'], ['Self Help', nan",
#        "'Classics', 'History', 'Memoir', 'Philosophy', 'Poetry'], ['Nonfiction', nan",
#        "'Audiobook', 'Classics', 'Crime', 'Detective'], 'Fiction', 'Mystery Thriller', ['Mystery', nan",
#        "'19th Century', 'Classic Literature'], 'Fiction', 'Historical Fiction', 'Literature', 'Novels', ['Classics', nan",
#        "'Childrens', 'Fairy Tales', 'Fantasy', 'Fiction', 'Literature'], 'Short Stories', ['Classics', nan",
#        "'American History', 'Classics', 'Nonfiction', 'Philosophy', 'Political Science'], 'Politics', ['History', nan",
#        "'Fiction', 'Gothic', 'Horror', 'Mystery', 'Short Stories', 'Victorian'], ['Classics', nan",
#        "'Crime', 'Fiction', 'Gothic'], 'Horror', 'Mystery', 'Short Stories', ['Classics', nan",
#        "'Ancient'], 'Epic', 'Greek Mythology', 'Historical Fiction', 'Historical', 'Literature', ['Mythology', nan",
#        "'Animals', 'Childrens', 'Fiction', 'Historical Fiction'], 'Horses', 'Young Adult', ['Classics', nan",
#        "'Adventure', 'American'], 'Fiction', 'Historical Fiction', 'Historical', 'Literature', ['Classics', nan",
#        "'Horror', 'Literature', 'Novels'], 'Philosophy', 'School', 'Short Stories', ['Fantasy', nan",
#        "'Classics', 'Historical Fiction'], 'Italian Literature', 'Italy', 'Literature', 'Short Stories', ['Fiction', nan",
#        "'Classics'], 'Fiction', ['Short Stories', nan",
#        "'Classics', 'Fantasy', 'Fiction', 'Mystery'], 'Short Stories', 'Vampires', ['Horror', nan",
#        "'Essays', 'History', 'Modern', 'Nonfiction', 'Politics', 'The United States Of America'], ['Philosophy', nan",
#        "['Animals'], nan",
#        "'Classics', 'Fantasy'], 'Fiction', 'Gothic', 'Horror', 'Short Stories', ['Poetry', nan",
#        "'Cyberpunk', 'Dystopia', 'Fiction', 'Science Fiction', 'Teen', 'Thriller'], ['Young Adult', nan",
#        "'Classics', 'Fiction', 'Historical Fiction', 'Horror', 'Literature', 'War'], ['Short Stories', nan",
#        "'Classics', 'German Literature', 'Germany'], 'Literature', 'Novels', 'Philosophy', ['Fiction', nan",
#        "'History', 'Nonfiction', 'Personal Development'], 'Psychology', 'Self Help', 'Spirituality', ['Philosophy', nan",
#        "'18th Century', 'Fantasy', 'Fiction', 'Gothic', 'Horror', 'Literature'], ['Classics', nan",
#        "'20th Century', 'Classics', 'Fiction', 'Literary Fiction', 'Literature', 'Womens'], ['Short Stories', nan",
#        "'Classics', 'Feminism', 'Fiction', 'Gothic', 'Horror', 'Mental Health'], ['Short Stories', nan",
#        "'Autobiography', 'Biography', 'Memoir'], 'Nonfiction', 'Philosophy', 'Religion', ['Spirituality', nan",
#        "'Fiction', 'Splatterpunk', 'Supernatural'], 'Thriller', ['Horror', nan",
#        "'20th Century', 'American', 'Classics', 'Literary Fiction'], 'Literature', 'Short Stories', ['Fiction', nan",
#        "'Audiobook', 'Classic Literature'], 'Fiction', 'Historical Fiction', 'Historical', 'Literature', ['Classics', nan",
#        "'Adventure', 'American', 'Fiction', 'Historical Fiction', 'Historical'], 'Literature', ['Classics', nan",
#        "'Classics', 'Fantasy', 'Fiction', 'Gothic', 'Paranormal'], 'Vampires', ['Horror', nan",
#        "'Crime', 'Detective', 'Fiction', 'Mystery Thriller'], 'Mystery', 'Short Stories', ['Classics', nan",
#        "'American', 'Fiction', 'Gothic', 'Historical Fiction', 'Horror'], 'Literature', ['Classics', nan",
#        "'20th Century'], 'Fiction', 'France', 'French Literature', 'Literature', 'Novels', ['Classics', nan",
#        "'Classics', 'Fiction', 'German Literature', 'Literary Fiction'], 'Literature', 'Philosophy', ['Short Stories', nan",
#        "'19th Century', 'British Literature'], 'Classics', 'Humor', 'Literature', 'Victorian', ['Fiction', nan",
#        "'Childrens', 'Classics', 'Fantasy', 'Literature', 'Mythology'], 'Short Stories', ['Fiction', nan",
#        "'Adventure', 'Fiction', 'France', 'Historical Fiction', 'Historical'], 'Literature', ['Classics', nan",
#        "'18th Century', 'British Literature'], 'Fiction', 'Humor', 'Literature', 'Novels', ['Classics', nan",
#        "'Drama', 'Fiction', 'France', 'Plays', 'Romance', 'Theatre'], ['Classics', nan",
#        "'Classics', 'Nonfiction', 'Philosophy', 'Psychoanalysis', 'Science', 'Theory'], ['Psychology', nan",
#        "'Adventure', 'Childrens', 'Fiction', 'Historical Fiction', 'Historical'], 'Young Adult', ['Classics', nan",
#        "'Classics', 'German Literature', 'Germany', 'Historical Fiction', 'Novels'], 'War', ['Fiction', nan",
#        "'19th Century', 'Fiction', 'Gothic', 'Historical Fiction', 'Romance'], 'Scotland', ['Classics', nan",
#        "'Adventure', 'Fiction', 'France', 'French Literature', 'Historical Fiction', 'Roman'], ['Classics', nan",
#        "'Essays', 'Fiction', 'Humor', 'Philosophy', 'School'], 'Short Stories', ['Classics', nan",
#        "'Anthologies', 'Fantasy', 'Fiction', 'Occult'], 'Short Stories', 'Supernatural', ['Horror', nan",
#        "'Classics', 'Fantasy', 'Fiction', 'Literature', 'Philosophy'], 'Religion', ['Poetry', nan",
#        "'Contemporary', 'Historical Fiction', 'Humor', 'Literature'], 'Novels', 'Politics', ['Fiction', nan",
#        "'Audiobook'], 'Crime', 'Detective', 'Fiction', 'Mystery', 'Short Stories', ['Classics', nan",
#        "'American', 'Americana', 'Classics', 'Fiction', 'Literature', 'The United States Of America'], ['Poetry', nan",
#        "'Classics', 'Essays', 'Humor', 'Literature'], 'Religion', 'Short Stories', ['Fiction', nan",
#        "'19th Century', 'Fiction', 'Historical Fiction'], 'Literature', 'Novels', 'Victorian', ['Classics', nan",
#        "'20th Century'], 'France', 'French Literature', 'Literature', 'Novels', 'Philosophy', ['Fiction', nan",
#        "'Africa', 'Autobiography'], 'Biography', 'Classics', 'Memoir', 'Nonfiction', ['History', nan",
#        "'Adventure', 'Fiction', 'Historical Fiction', 'Literature', 'Novels'], 'Spanish Literature', ['Classics', nan",
#        "'Autobiography'], 'Biography', 'Classics', 'History', 'Memoir', 'School', ['Nonfiction', nan",
#        "'20th Century'], 'Classics', 'Ireland', 'Irish Literature', 'Literature', 'Novels', ['Fiction', nan",
#        "'Adventure'], 'Childrens', 'Classics', 'Fiction', 'Literature', 'Young Adult', ['Fantasy', nan",
#        "['Mystery'], nan",
#        "'Classics', 'Fiction', 'Literature', 'Plays', 'Romance', 'School'], ['Poetry', nan",
#        "'20th Century'], 'Fiction', 'Ireland', 'Irish Literature', 'Literature', 'Short Stories', ['Classics', nan",
#        "'19th Century', 'Audiobook'], 'Fiction', 'Historical Fiction', 'Historical', 'Literature', ['Classics', nan",
#        "'20th Century', 'Classics', 'Historical Fiction', 'Literature', 'Novels'], 'Russia', ['Fiction', nan",
#        "'18th Century', 'British Literature', 'Fiction', 'Humor', 'Literature', 'Novels'], ['Classics', nan",
#        "'Audiobook', 'British Literature'], 'Fiction', 'Historical Fiction', 'Italy', 'Romance', ['Classics', nan",
#        "'Adventure', 'Childrens', 'Classics', 'Fiction', 'Middle Grade'], 'Young Adult', ['Fantasy', nan",
#        "'Classic Literature', 'Fantasy', 'Literary Fiction', 'Magical Realism', 'Novels'], 'Short Story Collection', ['Short Stories', nan",
#        "'Fiction', 'Gothic', 'Horror', 'Literature'], 'Mystery', 'Short Stories', ['Classics', nan",
#        "'Ancient', 'Classics', 'Greece'], 'History', 'Nonfiction', 'School', ['Philosophy', nan",
#        "'Adventure', 'Childrens', 'Fiction', 'Historical Fiction'], 'Literature', 'Young Adult', ['Classics', nan",
#        "'British Literature', 'Classics', 'Fiction', 'Literature', 'Philosophy'], 'Romanticism', ['Poetry', nan",
#        "'Fantasy'], 'Fiction', 'Gothic', 'Horror', 'Mystery', 'Short Stories', ['Classics', nan",
#        "'Fiction', 'Historical Fiction'], 'Horror', 'Read For School', 'School', 'Short Stories', ['Classics', nan",
#        "'American', 'Classics', 'Fiction', 'Literature', 'Read For School'], 'School', ['Poetry', nan",
#        "'Classics', 'Drama', 'Fiction', 'Historical Fiction', 'Poetry'], 'Theatre', ['Plays', nan",
#        "'Audiobook', 'Crime', 'Detective', 'Fiction', 'Mystery Thriller'], 'Mystery', ['Classics', nan",
#        "'Autobiography'], 'Biography', 'Classics', 'Historical', 'History', 'Memoir', ['Nonfiction', nan",
#        "'Crime', 'Fiction', 'France', 'Mystery Thriller'], 'Mystery', 'Short Stories', ['Classics', nan",
#        "'Classics', 'Essays', 'History'], 'Literature', 'Nonfiction', 'Poetry', ['Philosophy', nan",
#        "'19th Century', 'British Literature'], 'Classics', 'Literature', 'Romance', 'Victorian', ['Fiction', nan",
#        "'Classics', 'Essays', 'Language', 'Nonfiction', 'Psychology', 'Science'], ['Philosophy', nan",
#        "'Classic Literature'], 'Fiction', 'Historical Fiction', 'Historical', 'Literature', 'Romance', ['Classics', nan",
#        "'Classics', 'Essays', 'Logic', 'Nonfiction', 'Religion', 'Science'], ['Philosophy', nan",
#        "'American History', 'Classics', 'Essays'], 'Nonfiction', 'Philosophy', 'Politics', ['History', nan",
#        "'Fiction', 'Mythology', 'Plays', 'Read For School', 'School', 'Theatre'], ['Classics', nan",
#        "'19th Century'], 'Classics', 'France', 'French Literature', 'Literature', 'Romance', ['Fiction', nan",
#        "'Fiction', 'Gothic', 'Horror', 'Mystery'], 'School', 'Short Stories', ['Classics', nan",
#        "'Classics', 'Fiction', 'Literature', 'Philosophy', 'Short Stories', 'Spirituality'], ['Poetry', nan",
#        "'Nonfiction'], ['Poetry', nan",
#        "'Audiobook', 'Fiction', 'Gothic', 'Horror', 'Literature'], 'Mystery', ['Classics', nan",
#        "'Classics', 'Fiction', 'War'], ['Historical Fiction', nan",
#        "'American'], 'Fiction', 'Historical Fiction', 'Historical', 'Literature', 'Novels', ['Classics', nan",
#        "'Feminism', 'Fiction', 'Historical Fiction', 'Literature', 'Read For School'], 'School', ['Classics', nan",
#        "'Classics'], ['History', nan",
#        "'Anthropology', 'Genetics'], 'Nonfiction', 'Politics', 'Race', 'Research', ['History', nan",
#        "'Classics', 'Comedy'], 'Language', 'Nonfiction', 'Philosophy', 'Reference', ['Humor', nan",
#        "'Childrens', 'Classics', 'Fairy Tales', 'Fiction', 'Middle Grade', 'Young Adult'], ['Fantasy', nan",
#        "'Adventure', 'Fiction', 'Historical Fiction', 'Historical', 'Pirates', 'Romance'], ['Classics', nan",
#        "'Ancient History', 'Ancient', 'Classics', 'Greece', 'Nonfiction', 'Philosophy'], ['History', nan",
#        "'Art', 'British Literature', 'Criticism'], 'Music', 'Nonfiction', ['Essays', nan",
#        "'Audiobook', 'Classics', 'Crime', 'Detective', 'Fiction', 'Thriller'], ['Mystery', nan",
#        "'Christian', 'Faith', 'Inspirational', 'Religion'], ['Nonfiction', nan",
#        "'18th Century', 'British Literature'], 'Fiction', 'Literature', 'Novels', 'Romance', ['Classics', nan",
#        "'Fiction', 'Gothic'], 'Horror', 'Mystery', 'Poetry', 'Short Stories', ['Classics', nan",
#        "'Buddhism'], 'Fiction', 'Literature', 'Philosophy', 'Religion', 'Spirituality', ['Classics', nan",
#        "'Cultural'], 'India', 'Nonfiction', 'Poetry', 'Religion', 'Spirituality', ['Philosophy', nan",
#        "'Audiobook', 'Crime', 'Detective'], 'Fiction', 'Mystery Thriller', 'Thriller', ['Mystery', nan",
#        "'Classics', 'Fiction', 'Gothic', 'Mystery', 'Short Stories', 'Weird Fiction'], ['Horror', nan",
#        "'British Literature'], 'Crime', 'Fiction', 'Mystery Thriller', 'Plays', 'Short Stories', ['Mystery', nan",
#        "'Arthurian', 'Childrens', 'Classics', 'Fiction', 'Science Fiction Fantasy'], 'Young Adult', ['Fantasy', nan",
#        "'Fiction', 'Literature'], 'Mythology', 'Plays', 'Poetry', 'Theatre', ['Classics', nan",
#        "'Classics', 'Nonfiction', 'Philosophy', 'Psychoanalysis', 'Sociology', 'Theory'], ['Psychology', nan",
#        "'Classics'], 'Fantasy', 'Fiction', 'Gothic', 'Short Stories', 'Weird Fiction', ['Horror', nan",
#        "'Childrens', 'Classics', 'Fiction', 'Holiday'], 'Picture Books', 'Poetry', ['Christmas', nan",
#        "'Classics'], 'Essays', 'Nonfiction', 'Personal Development', 'Psychology', 'Self Help', ['Philosophy', nan",
#        "'Classics', 'Fairy Tales'], 'Fantasy', 'Literature', 'Mythology', 'Short Stories', ['Fiction', nan",
#        "'Adventure', 'Fiction', 'France', 'French Literature', 'Historical Fiction', 'Historical'], ['Classics', nan",
#        "'Adventure', 'Biography'], 'Classics', 'Memoir', 'Nonfiction', 'Travel', ['Nature', nan",
#        "'20th Century', 'Australia'], 'Fiction', 'Germany', 'Historical Fiction', 'Music', ['Classics', nan",
#        "'American', 'Classic Literature'], 'Classics', 'Collections', 'Fiction', 'Literature', ['Poetry', nan",
#        "'Adventure', 'Classics', 'Fantasy', 'Fiction', 'Pulp', 'Science Fiction Fantasy'], ['Science Fiction', nan",
#        "'Autobiography'], 'Biography', 'Feminism', 'History', 'Memoir', 'Politics', ['Nonfiction', nan",
#        "'Anthologies', 'Fiction', 'Science Fiction Fantasy', 'Science Fiction', 'Short Stories', 'Speculative Fiction'], ['Cyberpunk', nan",
#        "'Adventure', 'English Literature'], 'Fantasy', 'Fiction', 'Humor', 'Literature', ['Classics', nan",
#        "'Animals', 'Childrens', 'Fantasy', 'Fiction', 'Picture Books', 'Young Adult'], ['Classics', nan",
#        "'Classics', 'Crime', 'Detective', 'Fiction', 'Mystery Thriller', 'Thriller'], ['Mystery', nan",
#        "'Christian'], 'Christmas', 'Classics', 'Literature', 'Religion', 'Short Stories', ['Fiction', nan",
#        "'Erotica', 'Fiction', 'France', 'French Literature'], 'Horror', 'Philosophy', ['Classics', nan",
#        "'Fiction', 'Ghosts'], 'Gothic', 'Horror', 'Literature', 'Short Stories', ['Classics', nan",
#        "'Classics', 'Fiction', 'Ghost Stories'], 'Ghosts', 'Gothic', 'Short Stories', ['Horror', nan",
#        "'18th Century'], 'Adventure', 'Classics', 'Historical Fiction', 'Literature', 'Novels', ['Fiction', nan",
#        "'Fantasy', 'Fiction', 'Literature', 'Mythology', 'Poetry', 'School'], ['Classics', nan",
#        "'Fiction', 'Gothic', 'Horror', 'Literature'], 'Poetry', 'Short Stories', ['Classics', nan",
#        "'American'], 'Fiction', 'Historical Fiction', 'Literature', 'Romance', 'School', ['Classics', nan",
#        "'Autobiography', 'Biography Memoir', 'Biography', 'Classics'], 'History', 'Memoir', ['Nonfiction', nan",
#        "'Classics', 'History', 'Literature'], 'Medieval', 'Nonfiction', 'Poetry', ['Mythology', nan",
#        "'Classics', 'Fantasy', 'Fiction', 'Gothic'], 'Short Stories', 'Weird Fiction', ['Horror', nan",
#        "'Africa', 'Fiction', 'Historical Fiction', 'Literature', 'Novels'], 'School', ['Classics', nan",
#        "'Childrens'], 'Fantasy', 'Fiction', 'Literature', 'Romance', 'Short Stories', ['Classics', nan",
#        "'Fiction', 'Historical Fiction', 'Historical'], 'Japan', 'Japanese Literature', 'Literature', ['Classics', nan",
#        "'Classics', 'Historical Fiction', 'India', 'Indian Literature', 'Literature'], 'Novels', ['Fiction', nan",
#        "'Classics', 'History', 'Literature'], 'Nonfiction', 'Politics', 'School', ['Philosophy', nan",
#        "'19th Century', 'Fiction', 'France', 'French Literature', 'Literature', 'Novels'], ['Classics', nan",
#        "'Childrens', 'Fiction', 'Historical Fiction', 'Historical'], 'Romance', 'Young Adult', ['Classics', nan",
#        "'18th Century', 'Classics', 'Drama', 'Fiction', 'Humor'], 'Theatre', ['Plays', nan",
#        "'Classics', 'Fantasy', 'Fiction', 'Mystery'], 'Pirates', 'Weird Fiction', ['Horror', nan",
#        "'Classics', 'Essays'], 'Nonfiction', 'Philosophy', 'Psychoanalysis', 'Science', ['Psychology', nan",
#        "'Childrens', 'Fiction', 'Historical Fiction', 'Novels'], 'Romance', 'Young Adult', ['Classics', nan",
#        "'Fantasy', 'Paranormal Romance', 'Paranormal', 'Romance', 'Supernatural'], 'Young Adult', ['Vampires', nan",
#        "'Adventure', 'Fiction', 'High Fantasy'], 'Science Fiction Fantasy', 'Science Fiction', 'Speculative Fiction', ['Fantasy', nan",
#        "'Adult', 'Classics', 'Contemporary', 'Dark'], 'Poetry', 'Romance', ['Fiction', nan",
#        "'Fantasy', 'Feminism'], 'Fiction', 'Historical Fiction', 'LGBT', 'Queer', ['Classics', nan",
#        "'Classics', 'Essays', 'German Literature'], 'Nonfiction', 'Philosophy', 'Writing', ['Poetry', nan",
#        "'Art', 'Biography', 'Classics', 'LGBT', 'Memoir', 'Queer'], ['Nonfiction', nan",
#        "'Adventure', 'Classics', 'Fiction', 'Historical Fiction', 'Historical'], 'Romance', ['Westerns', nan",
#        "'Classics', 'History', 'Nonfiction', 'Politics'], 'Reference', 'Religion', ['Philosophy', nan"],
#       dtype=object)

# %%
df["genre"] = (
    df["genre"]
    .astype(str)
    .str.replace(", nan", "", regex=False)
    .str.replace("['", "", regex=False)
    .str.replace("']", "", regex=False)
    .str.replace("']", "", regex=False)
    .str.replace("  ", " ")
    .str.strip()
)

# %%
df["genre"].unique()
# Out:
# array(["'Audiobook, 'Crime', 'Fiction', 'Mystery Thriller', 'Suspense', 'Thriller', Mystery;Thriller;Mystery,Crime;Fiction;Suspense;Thriller,Mystery Thriller;Audiobook;Adult;Mystery,Detective;Contemporary, Mystery'",
#        "'Adventure', 'Classics', 'Fantasy, 'Horror', 'Science Fiction', 'Thriller', Fiction;Science Fiction;Thriller;Adventure;Horror;Mystery;Suspense;Cultural,Africa;Novels;Thriller,Mystery Thriller, Fiction'",
#        "'Contemporary', 'Historical Fiction', 'Literature', 'Novels, 'Turkish Literature', 'Turkish', Fiction'",
#        "'Audiobook', 'Crime', 'Fiction', 'Mystery Thriller, 'Mystery', 'Thriller', Fantasy;Fiction;Horror;Science Fiction;Adventure;Westerns;Audiobook;Science Fiction Fantasy;Thriller;Apocalyptic,Post Apocalyptic, Horror'",
#        "'Entrepreneurship, 'Finance', 'Nonfiction', 'Personal Development', 'Productivity', 'Self Help', Business'",
#        "'Adult, 'Crime', 'Fiction', 'Mystery Thriller', 'Suspense', 'Thriller', Mystery'",
#        "'Adventure', 'Fiction', 'Magic, 'Middle Grade', 'Romance', 'Young Adult', Fantasy'",
#        "'Fantasy', 'Fiction, 'Magic', 'Paranormal', 'Romance', 'Witches', Young Adult'",
#        "'Biography, 'Comics', 'LGBT', 'Memoir', 'Nonfiction', 'Queer', Graphic Novels'",
#        "'Adventure', 'Classics', 'Fantasy, 'France', 'Science Fiction', 'Travel', Fiction'",
#        "'Adult, 'British Literature', 'Fiction', 'Historical', 'Romance', 'Tudor Period', Historical Fiction'",
#        "'Fantasy', 'Fiction', 'Mystery', 'Short Stories', 'Suspense, 'Thriller', Horror'",
#        "'Biology', 'Nonfiction', 'Philosophy', 'Politics, 'Science', 'Sociology', Psychology'",
#        "'Classics, 'Essays', 'France', 'French Literature', 'Literature', 'Nonfiction', Philosophy'",
#        "'Adventure, 'Dystopia', 'Fantasy', 'Fiction', 'Horror', 'Science Fiction', Young Adult'",
#        "'Audiobook, 'Classics', 'Fantasy', 'Fiction', 'Science Fiction Fantasy', 'Space Opera', Science Fiction'",
#        "'Audiobook', 'Biology', 'Health', 'Medical, 'Medicine', 'Science', Nonfiction'",
#        "'Classics, 'Comedy', 'Fantasy', 'Fiction', 'Humor', 'Science Fiction Fantasy', Science Fiction'",
#        "'Adventure', 'Classics', 'Fiction', 'Middle Grade, 'Mystery', 'Young Adult', Childrens'",
#        "'Business', 'Communication', 'Nonfiction', 'Personal Development', 'Psychology', 'Relationships, Self Help'",
#        "'Adult Fiction', 'Adult', 'Audiobook, 'Chick Lit', 'Contemporary', 'Fiction', Romance'",
#        "'Fiction', 'Historical Fiction', 'Historical', 'Medieval', 'Romance', 'Scotland, Historical Romance'",
#        "'Fairy Tales', 'Fiction, 'Historical Fiction', 'Retellings', 'Romance', 'Young Adult', Fantasy'",
#        "'Classics', 'Historical', 'History', 'Mystery', 'Nonfiction', 'Occult, Art'",
#        "'Classics', 'Contemporary', 'Literary Fiction', 'Mystery Thriller, 'Mystery', 'Thriller', Fiction'",
#        "'Biography', 'Chick Lit', 'Memoir', 'Romance', 'Spirituality, 'Travel', Nonfiction'",
#        "'Adult, 'Audiobook', 'Autobiography', 'Biography', 'Memoir', 'Mental Health', Nonfiction'",
#        "'American History', 'American Revolution', 'Audiobook, 'Historical', 'Nonfiction', 'War', History'",
#        "'Fae', 'Fantasy Romance, 'Fiction', 'New Adult', 'Romance', 'Young Adult', Fantasy'",
#        "'Adventure, 'American', 'Fiction', 'Literature', 'Novels', 'School', Classics'",
#        "'Chick Lit', 'Contemporary', 'Fiction', 'Realistic Fiction, 'Romance', 'Teen', Young Adult'",
#        "'Classics', 'Contemporary', 'Crime', 'Literature, 'Novels', 'Scotland', Fiction'",
#        "'Adventure, 'Dragons', 'Fiction', 'Science Fiction Fantasy', 'Science Fiction', 'Young Adult', Fantasy'",
#        "'Fiction', 'Horror', 'New Weird, 'Science Fiction', 'Short Stories', 'Weird Fiction', Fantasy'",
#        "'Fantasy', 'Fiction', 'Medieval', 'Mythology, 'Poetry', 'School', Classics'",
#        "'Christianity', 'Classics', 'Nonfiction', 'Russia', 'Spirituality, 'Theology', Philosophy'",
#        "'Dystopia', 'Fiction, 'Retellings', 'Science Fiction', 'Short Stories', 'Young Adult', Fantasy'",
#        "'Classics', 'Fiction', 'Literature, 'Philosophy', 'Religion', 'Spirituality', Poetry'",
#        "'Gender Studies, 'Gender', 'Nonfiction', 'Philosophy', 'Queer', 'Theory', Feminism'",
#        "'Audiobook', 'Mental Health', 'Personal Development', 'Psychology', 'Self Help', 'Spirituality, Nonfiction'",
#        "'Audiobook, 'Business', 'Personal Development', 'Productivity', 'Psychology', 'Self Help', Nonfiction'",
#        "'Fiction', 'Military Fiction', 'Science Fiction Fantasy', 'Space Opera', 'Space, 'War', Science Fiction'",
#        "'Fantasy', 'Fiction', 'Historical Fiction', 'Supernatural, 'Thriller', 'Vampires', Horror'",
#        "'Adult Fiction', 'Chick Lit', 'Contemporary', 'Fantasy', 'Fiction', 'Womens Fiction, Romance'",
#        "'Audiobook, 'Dystopia', 'Fantasy', 'Fiction', 'Romance', 'Science Fiction', Young Adult'",
#        "'British Literature', 'Feminism', 'Fiction', 'Literary Fiction, 'Literature', 'Novels', Classics'",
#        "'Adventure', 'Childrens', 'Classics', 'Fiction', 'Magic', 'Middle Grade, Fantasy'",
#        "'Adventure', 'Dragons', 'Fiction, 'Magic', 'Science Fiction Fantasy', 'Urban Fantasy', Fantasy'",
#        "'Audiobook, 'Crime', 'Detective', 'Fiction', 'Italian Literature', 'Italy', Mystery'",
#        "'Contemporary', 'High School, 'New Adult', 'Sports Romance', 'Sports', 'Young Adult', Romance'",
#        "'Classics', 'Dystopia', 'Fantasy', 'Fiction', 'Post Apocalyptic', 'Young Adult, Science Fiction'",
#        "'Adventure', 'Epic Fantasy, 'Fiction', 'High Fantasy', 'Science Fiction Fantasy', 'Science Fiction', Fantasy'",
#        "'Classics', 'Fiction', 'Literature, 'Philosophy', 'Science Fiction Fantasy', 'Short Stories', Science Fiction'",
#        "'Classics, 'Fantasy', 'Fiction', 'Humor', 'Polish Literature', 'Short Stories', Science Fiction'",
#        "'Adult', 'Audiobook', 'Chick Lit, 'Contemporary Romance', 'Contemporary', 'Fiction', Romance'",
#        "'19th Century', 'Classics', 'Drama', 'Fiction', 'Literature, 'Theatre', Plays'",
#        "'German Literature', 'Germany', 'Historical Fiction', 'Historical', 'Novels', 'Travel, Fiction'",
#        "'Inspirational, 'Literature', 'Novels', 'Philosophy', 'Self Help', 'Short Stories', Fiction'",
#        "'Crime', 'Fiction', 'Mystery Thriller', 'Scandinavian Literature', 'Sweden, 'Thriller', Mystery'",
#        "'Audiobook', 'Crime', 'Fiction', 'Mystery Thriller, 'Mystery', 'Thriller', Horror'",
#        "'Classics', 'German Literature', 'History, 'Nonfiction', 'Psychology', 'Theory', Philosophy'",
#        "'18th Century', 'Classics', 'Fantasy', 'Fiction', 'Horror', 'Literature, Gothic'",
#        "'Adventure', 'Fiction', 'France, 'Historical Fiction', 'Historical', 'Literature', Classics'",
#        "'Audiobook', 'Crime', 'Fiction', 'Mystery', 'Paranormal, 'Thriller', Horror'",
#        "'Fiction', 'Literature', 'Poetry', 'Politics, 'Short Stories', 'War', Classics'",
#        "'Africa', 'Botswana', 'Crime', 'Detective', 'Fiction', 'Mystery Thriller, Mystery'",
#        "'Adult, 'Fantasy', 'Paranormal Romance', 'Paranormal', 'Urban Fantasy', 'Vampires', Romance'",
#        '[]',
#        "'20th Century, 'American', 'Classics', 'Literary Fiction', 'Literature', 'Novels', Fiction'",
#        "'Classics', 'Fantasy', 'Fiction', 'Humor, 'Middle Grade', 'Young Adult', Childrens'",
#        "'Fantasy', 'Fiction', 'Paranormal', 'Supernatural, 'Thriller', 'Vampires', Horror'",
#        "'Contemporary', 'Football', 'Mystery', 'Novels, 'Sports', 'Thriller', Fiction'",
#        "'Adventure, 'Childrens', 'Classics', 'Fiction', 'Finnish Literature', 'Scandinavian Literature', Fantasy'",
#        "'Classics', 'Epic, 'Fiction', 'Literature', 'Mythology', 'Nobel Prize', Poetry'",
#        "'Adventure', 'Fantasy', 'Fiction', 'France', 'Literature, 'Science Fiction', Classics'",
#        "'19th Century', 'Classics', 'Drama', 'Fiction', 'Scandinavian Literature, 'Theatre', Plays'",
#        "'Adventure, 'Childrens', 'Classics', 'Fiction', 'Finnish Literature', 'Middle Grade', Fantasy'",
#        "'Dark Fantasy', 'Fantasy', 'Fiction', 'LGBT', 'Mystery, 'Supernatural', Horror'",
#        "'Book Club', 'Contemporary', 'Literary Fiction', 'Novels', 'Relationships, 'Romance', Fiction'",
#        "'Drama', 'Fiction', 'Literature, 'Mythology', 'Plays', 'School', Classics'",
#        "'Adventure', 'Classics', 'France', 'French Literature', 'Historical Fiction', 'Novels, Fiction'",
#        "'Animals', 'Childrens', 'Fantasy', 'Fiction', 'Literature, 'Short Stories', Classics'",
#        "'Adventure', 'Bande Dessinée', 'Childrens', 'Comic Book, 'Fiction', 'Graphic Novels', Comics'",
#        "'Audiobook, 'Biography Memoir', 'Business', 'History', 'Nonfiction', 'Technology', Biography'",
#        "'Biography', 'History', 'Holocaust', 'Memoir', 'War, 'World War II', Nonfiction'",
#        "'Audiobook', 'Fiction', 'Horror', 'Science Fiction Fantasy', 'Science Fiction, 'Urban Fantasy', Fantasy'",
#        "'Adventure', 'Asia, 'Biography', 'History', 'Memoir', 'Travel', Nonfiction'",
#        "'Classics', 'Essays', 'France', 'French Literature, 'History', 'Nonfiction', Philosophy'",
#        "'European History, 'Germany', 'Nonfiction', 'Politics', 'War', 'World War II', History'",
#        "'Adventure', 'Bande Dessinée', 'Fiction', 'France', 'Graphic Novels Comics, 'Graphic Novels', Comics'",
#        "'Academic, 'Economics', 'Military Fiction', 'Military History', 'Nonfiction', 'War', History'",
#        "'Classics', 'Dragons, 'Fiction', 'High Fantasy', 'Magic', 'Young Adult', Fantasy'",
#        "'Childrens', 'Classics', 'Fiction', 'Finnish Literature', 'Middle Grade', 'Scandinavian Literature, Fantasy'",
#        "'Audiobook', 'Business, 'Personal Development', 'Psychology', 'Science', 'Self Help', Nonfiction'",
#        "'Classics, 'Holocaust', 'Nonfiction', 'Philosophy', 'Politics', 'Psychology', History'",
#        "'American History, 'Military Fiction', 'Military History', 'Nonfiction', 'Politics', 'War', History'",
#        "'Biography', 'Classics, 'Memoir', 'Philosophy', 'Psychology', 'Self Help', Nonfiction'",
#        "'Contemporary, 'Crime', 'Fiction', 'Mystery Thriller', 'Thriller', 'Young Adult', Mystery'",
#        "'Audiobook', 'Biography', 'Humor', 'Memoir', 'Nonfiction', 'Travelogue, Travel'",
#        "'Adventure', 'Audiobook, 'Fiction', 'Historical', 'Novels', 'Travel', Historical Fiction'",
#        "'Nonfiction', 'Philosophy', 'Psychology', 'Religion, 'Self Help', 'Spirituality', Buddhism'",
#        "'Classics', 'Drama', 'Fiction', 'Romance', 'School', 'Theatre, Plays'",
#        "'Classics', 'Fantasy', 'Gothic', 'Literature, 'Mystery', 'Science Fiction', Horror'",
#        "'Crime', 'Fiction', 'Mystery Thriller', 'Romance, 'Suspense', 'Thriller', Mystery'",
#        "'Crime', 'Fiction', 'Horror', 'Mystery Thriller', 'Suspense, 'Thriller', Mystery'",
#        "'Biography Memoir', 'British Literature, 'History', 'Literary Criticism', 'Literature', 'Nonfiction', Biography'",
#        "'Fiction', 'Literature', 'Plays', 'Read For School, 'School', 'Theatre', Classics'",
#        "'Ancient History, 'Ancient', 'Classics', 'History', 'Nonfiction', 'School', Philosophy'",
#        "'Fantasy', 'Fiction', 'Mystery', 'Paranormal', 'Thriller, 'Young Adult', Horror'",
#        "'Classics', 'Literature, 'Magical Realism', 'Poland', 'Polish Literature', 'Short Stories', Fiction'",
#        "'Canada', 'Canadian Literature', 'Classics', 'Contemporary', 'Feminism, 'Literary Fiction', Fiction'",
#        "'Drama', 'Fiction', 'German Literature', 'Literature, 'Plays', 'Poetry', Classics'",
#        "'18th Century, 'Adventure', 'Classics', 'Fantasy', 'Literature', 'Novels', Fiction'",
#        "'Audiobook', 'Historical, 'Military Fiction', 'Nonfiction', 'War', 'World War II', History'",
#        "'Fantasy', 'Fiction', 'Gothic, 'Horror', 'Humor', 'Short Stories', Classics'",
#        "'Ancient History', 'Classics', 'Greece, 'Nonfiction', 'Politics', 'War', History'",
#        "'Adventure, 'Classics', 'Fiction', 'Humor', 'Romance', 'Young Adult', Fantasy'",
#        "'Adventure', 'Cyberpunk', 'Fiction', 'Science Fiction Fantasy', 'Science Fiction', 'Speculative Fiction, Fantasy'",
#        "'Fantasy', 'Fiction', 'Paranormal, 'Supernatural', 'Thriller', 'Werewolves', Horror'",
#        "'Classics', 'Drama', 'Fantasy', 'Fiction', 'School', 'Theatre, Plays'",
#        "'Contemporary Romance', 'Contemporary', 'Erotica', 'New Adult, 'Sports Romance', 'Sports', Romance'",
#        "'Business', 'Classics', 'History', 'Military Fiction, 'Philosophy', 'War', Nonfiction'",
#        "'Adult', 'Contemporary Romance', 'Contemporary', 'Erotica, 'Music', 'New Adult', Romance'",
#        "'British Literature, 'Chick Lit', 'Drama', 'Historical Fiction', 'Historical', 'Romance', Fiction'",
#        "'Chick Lit', 'Contemporary, 'Historical Fiction', 'Ireland', 'Irish Literature', 'Romance', Fiction'",
#        "'Adventure', 'Fantasy, 'Historical Fiction', 'Historical', 'Pirates', 'Thriller', Fiction'",
#        "'Drama, 'Fiction', 'Historical Fiction', 'Literature', 'Novels', 'Romance', Classics'",
#        "'Classics', 'Fantasy', 'Fiction', 'Literature, 'Mythology', 'School', Poetry'",
#        "'Business', 'Leadership, 'Nonfiction', 'Personal Development', 'Science', 'Self Help', Psychology'",
#        "'Classics, 'Historical Fiction', 'Literature', 'Novels', 'Russia', 'Russian Literature', Fiction'",
#        "'Adult, 'Contemporary Romance', 'Contemporary', 'Humor', 'Music', 'New Adult', Romance'",
#        "'Fiction', 'Historical Fiction', 'Historical Romance', 'Historical', 'Love Story, 'Romantic', Romance'",
#        "'British Literature', 'Historical Fiction', 'Historical', 'Romance', 'War, 'World War II', Fiction'",
#        "'Fantasy', 'Mythology, 'Paranormal', 'Romance', 'Urban Fantasy', 'Vampires', Paranormal Romance'",
#        "'Audiobook, 'Classics', 'Crime', 'Detective', 'Fiction', 'Mystery Thriller', Mystery'",
#        "'Adventure', 'Childrens', 'Fiction', 'Magic, 'Middle Grade', 'Young Adult', Fantasy'",
#        "'Fiction, 'Historical Fiction', 'Historical', 'Regency Romance', 'Regency', 'Romance', Historical Romance'",
#        "'Biography', 'Crime', 'Historical, 'History', 'Mystery', 'True Crime', Nonfiction'",
#        "'Apocalyptic, 'Audiobook', 'Dystopia', 'Fantasy', 'Fiction', 'Post Apocalyptic', Science Fiction'",
#        "'Anthologies, 'Fantasy', 'Fiction', 'Historical Fiction', 'Magical Realism', 'Science Fiction', Short Stories'",
#        "'Adult Fiction', 'Chick Lit', 'Contemporary Romance', 'Contemporary', 'Fiction', 'Womens Fiction, Romance'",
#        "'Asia, 'Classics', 'Historical Fiction', 'Japan', 'Japanese Literature', 'Literature', Fiction'",
#        "'Biography, 'Classics', 'Literature', 'Memoir', 'Nature', 'Nonfiction', Philosophy'",
#        "'Classics', 'Mathematics', 'Nonfiction', 'Philosophy', 'Physics', 'Popular Science, Science'",
#        "'College, 'Contemporary Romance', 'Contemporary', 'New Adult', 'Novella', 'Young Adult', Romance'",
#        "'Adventure', 'Fantasy', 'Fiction', 'Historical', 'Medieval', 'War, Historical Fiction'",
#        "'18th Century, 'Classics', 'German Literature', 'Metaphysics', 'Nonfiction', 'Science', Philosophy'",
#        "'Classics, 'History', 'Nonfiction', 'Politics', 'Religion', 'Theology', Philosophy'",
#        "'Audiobook', 'Personal Development', 'Philosophy', 'Psychology', 'Self Help', 'Unfinished, Nonfiction'",
#        "'Audiobook', 'Crime', 'Fiction', 'Mystery Thriller, 'Scotland', 'Thriller', Mystery'",
#        "'Adult, 'Fiction', 'Historical Fiction', 'Historical', 'Regency', 'Romance', Historical Romance'",
#        "'Classics', 'History', 'Nonfiction', 'Political Science', 'Politics', 'School, Philosophy'",
#        "'Audiobook', 'Fiction', 'High Fantasy, 'Romance', 'Young Adult Fantasy', 'Young Adult', Fantasy'",
#        "'Classics', 'Fiction', 'Mystery', 'Novels, 'Robots', 'Science Fiction Fantasy', Science Fiction'",
#        "'Audiobook, 'Fantasy', 'Fiction', 'Science Fiction Fantasy', 'Science Fiction', 'Speculative Fiction', Short Stories'",
#        "'Fiction', 'Horror', 'Paranormal', 'Supernatural, 'Vampires', 'Young Adult', Fantasy'",
#        "'Action, 'Adventure', 'Fiction', 'Mythology', 'Teen', 'Young Adult', Fantasy'",
#        "'Asian Literature, 'Classics', 'Japan', 'Japanese Literature', 'Literature', 'Novels', Fiction'",
#        "'Adult', 'Adventure', 'Audiobook', 'Fiction', 'Space', 'Thriller, Science Fiction'",
#        "'Audiobook', 'Fiction', 'Science Fiction Fantasy', 'Space Opera', 'Space', 'Speculative Fiction, Science Fiction'",
#        "'Audiobook', 'Crime', 'Horror', 'Mystery Thriller, 'Mystery', 'Thriller', Fiction'",
#        "'Adventure', 'Fiction', 'Historical Fiction', 'Literature, 'Scotland', 'Young Adult', Classics'",
#        "'Classics', 'Fantasy', 'Fiction', 'Gothic, 'Literature', 'School', Poetry'",
#        "'Essays', 'France', 'Mythology', 'Nonfiction', 'Sociology, 'Theory', Philosophy'",
#        "'Animals', 'Cats', 'Chapter Books, 'Childrens', 'Fiction', 'Middle Grade', Fantasy'",
#        "'Classics, 'Collections', 'Fantasy', 'Fiction', 'Horror', 'Short Stories', Science Fiction'",
#        "'Business, 'Classics', 'History', 'Nonfiction', 'Philosophy', 'Politics', Economics'",
#        "'Drama', 'Fiction', 'Historical Fiction', 'Literature, 'Plays', 'Theatre', Classics'",
#        "'Biology', 'Classics', 'Evolution', 'History, 'Nonfiction', 'Philosophy', Science'",
#        "'Love', 'Philosophy', 'Psychology', 'Relationships', 'Romance', 'Self Help, Fiction'",
#        "'Audiobook', 'Classics, 'Crime', 'Detective', 'Fiction', 'Mystery Thriller', Mystery'",
#        "'Classics', 'France', 'French Literature', 'Humor, 'Literature', 'Philosophy', Fiction'",
#        "'Action', 'Adventure', 'Espionage', 'Military Fiction', 'Suspense, 'Thriller', Fiction'",
#        "'Classics', 'Dystopia', 'Fiction', 'Horror', 'Novels', 'Science Fiction Fantasy, Science Fiction'",
#        "'Classics', 'Drama', 'Fiction', 'Mythology', 'Theatre', 'Tragedy, Plays'",
#        "'Classics', 'Drama', 'Feminism, 'Fiction', 'School', 'Theatre', Plays'",
#        "'Finance', 'Money', 'Nonfiction', 'Personal Development', 'Psychology, 'Self Help', Business'",
#        "'18th Century, 'Art', 'British Literature', 'Fiction', 'Greece', 'Historical', Historical Fiction'",
#        "'Adventure', 'Audiobook, 'Classics', 'Dinosaurs', 'Fantasy', 'Fiction', Science Fiction'",
#        "'Drama', 'Fiction', 'Humor', 'Literature', 'Plays', 'Theatre, Classics'",
#        "'Fiction', 'Horror', 'Novels, 'Occult', 'Science Fiction', 'Speculative Fiction', Fantasy'",
#        "'Classics', 'Drama, 'German Literature', 'Literature', 'Plays', 'Poetry', Fiction'",
#        "'20th Century, 'Classics', 'France', 'Nonfiction', 'Psychology', 'Theory', Philosophy'",
#        "'Contemporary', 'Fiction', 'High School, 'Mental Health', 'Realistic Fiction', 'Teen', Young Adult'",
#        "'Adult Fiction, 'Chick Lit', 'Contemporary', 'Ireland', 'Irish Literature', 'Romance', Fiction'",
#        "'Classics', 'Fantasy', 'Fiction', 'Novels, 'Science Fiction Fantasy', 'Space Opera', Science Fiction'",
#        "'Audiobook, 'Chick Lit', 'Contemporary', 'Fiction', 'France', 'Novels', Romance'",
#        "'Classics', 'Essays', 'Feminism', 'Literature, 'Philosophy', 'Politics', Nonfiction'",
#        "'Dark Fantasy', 'Fiction', 'Horror', 'Novels, 'Science Fiction Fantasy', 'Science Fiction', Fantasy'",
#        "'Fiction', 'Historical Fiction', 'Historical', 'Literature', 'Novels', 'School, Classics'",
#        "'18th Century', 'British Literature', 'Fiction', 'Historical Fiction', 'Literature', 'Novels, Classics'",
#        "'Audiobook', 'Chick Lit', 'Contemporary', 'Drama, 'Family', 'Fiction', Romance'",
#        "'Audiobook', 'Historical Fiction', 'Historical Romance, 'Historical', 'Literature', 'Novels', Fiction'",
#        "'College', 'Contemporary Romance, 'Contemporary', 'New Adult', 'Sports Romance', 'Sports', Romance'",
#        "'Adult, 'Audiobook', 'Chick Lit', 'Contemporary', 'Historical Fiction', 'Romance', Fiction'",
#        "'Fiction', 'Historical Fiction', 'Literature, 'Romance', 'Russia', 'Russian Literature', Classics'",
#        "'20th Century', 'Feminism', 'Fiction', 'Literary Fiction, 'Literature', 'Novels', Classics'",
#        "'Animals', 'Childrens', 'Fantasy', 'Fiction', 'Middle Grade, 'Young Adult', Classics'",
#        "'Fantasy', 'Fiction', 'Gothic', 'Literature, 'School', 'Science Fiction', Horror'",
#        "'Audiobook', 'Contemporary, 'Fiction', 'Historical', 'Mystery', 'Romance', Historical Fiction'",
#        "'Fiction', 'Historical Fiction, 'Literature', 'Poetry', 'School', 'Short Stories', Classics'",
#        "'19th Century', 'British Literature, 'Fiction', 'Historical Fiction', 'Literature', 'Victorian', Classics'",
#        "'18th Century', 'British Literature, 'Historical', 'History', 'Literature', 'Nonfiction', Classics'",
#        "'Ancient History', 'Ancient', 'Biography', 'Classics', 'Historical, 'Nonfiction', History'",
#        "'Fiction', 'Historical', 'Literature, 'Mystery', 'Romance', 'Russia', Historical Fiction'",
#        "'19th Century', 'Fiction', 'Gothic', 'Literature, 'Romance', 'Victorian', Classics'",
#        "'Adventure', 'Childrens', 'Classics', 'Fantasy', 'Fiction', 'Young Adult, Picture Books'",
#        "'Adventure, 'Childrens', 'Classics', 'Fiction', 'Middle Grade', 'Young Adult', Fantasy'",
#        "'British Literature', 'Crime', 'Fiction', 'Mystery Thriller', 'Suspense, 'Thriller', Mystery'",
#        "'Fiction', 'Ghost Stories', 'Ghosts', 'Gothic', 'Mystery, 'Paranormal', Horror'",
#        "'Fantasy, 'Fiction', 'Literature', 'Mythology', 'Poetry', 'School', Classics'",
#        "'British Literature, 'Gothic', 'Horror', 'Literature', 'Mystery', 'Novels', Classics'",
#        "'Dystopia', 'Fiction', 'Literature', 'Philosophy', 'Politics', 'School, Classics'",
#        "'Fiction', 'Japan', 'Japanese Literature', 'Mystery', 'Paranormal, 'Thriller', Horror'",
#        "'Adult', 'Audiobook, 'Chick Lit', 'Contemporary Romance', 'Contemporary', 'Fiction', Romance'",
#        "'19th Century, 'Fiction', 'Literature', 'Novels', 'Russia', 'Russian Literature', Classics'",
#        "'Business, 'Classics', 'History', 'Japan', 'Martial Arts', 'Nonfiction', Philosophy'",
#        "'19th Century', 'Fiction', 'France', 'French Literature', 'Historical Fiction, 'Literature', Classics'",
#        "'Audiobook, 'Fiction', 'Historical Fiction', 'Historical', 'Middle Grade', 'Young Adult', Mystery'",
#        "'Fantasy', 'Fiction', 'Literature, 'Plays', 'School', 'Theatre', Classics'",
#        "'Classics, 'Dystopia', 'Fantasy', 'Fiction', 'Middle Grade', 'Science Fiction', Young Adult'",
#        "'Classics', 'German Literature', 'Germany', 'Literature', 'Novels, 'Romance', Fiction'",
#        "'19th Century, 'Childrens', 'Fairy Tales', 'Fantasy', 'Fiction', 'Short Stories', Classics'",
#        "'Ancient, 'Classics', 'History', 'Nonfiction', 'Political Science', 'Politics', Philosophy'",
#        "'Classics', 'Crime', 'Detective, 'Fiction', 'Horror', 'Short Stories', Mystery'",
#        "'Classics', 'History', 'Personal Development', 'Psychology', 'Self Help', 'Spirituality, Nonfiction'",
#        "'Fiction', 'Gothic', 'Historical Fiction, 'Horror', 'Mystery', 'Romance', Classics'",
#        "'Adventure, 'Childrens', 'Fantasy', 'Fiction', 'Italian Literature', 'Italy', Classics'",
#        "'Fiction', 'Gothic', 'Historical Fiction', 'Historical Romance', 'Historical, 'Mystery', Romance'",
#        "'Drama', 'Fiction', 'Literature, 'Plays', 'Read For School', 'School', Classics'",
#        "'Drama', 'Fiction', 'Literature', 'Plays', 'Poetry', 'Reference, Classics'",
#        "'Childrens', 'Classics', 'Historical Fiction', 'Historical', 'Literature, 'Young Adult', Fiction'",
#        "'19th Century', 'Horror, 'Plays', 'Romanticism', Classics'",
#        "'Christian', 'Christianity', 'Classics', 'History, 'Nonfiction', 'Philosophy', Religion'",
#        "'Fiction', 'Gay, 'LGBT', 'Literary Fiction', 'Queer', 'Romance', Classics'",
#        "'20th Century', 'American', 'Classics', 'Historical Fiction, 'Literature', 'Novels', Fiction'",
#        "'Classics', 'Fiction, 'LGBT', 'Lesbian', 'Mythology', 'Queer', Poetry'",
#        "'Classics, 'Fantasy', 'Fiction', 'Japan', 'Japanese Literature', 'Short Stories', Horror'",
#        "'Adventure', 'Animals', 'Classics', 'Historical Fiction', 'Literature, 'Young Adult', Fiction'",
#        "'American', 'Classics', 'Fantasy', 'Novels, 'Science Fiction', 'The United States Of America', Fiction'",
#        "'19th Century, 'Brazil', 'Fiction', 'Literature', 'Portuguese Literature', 'Romance', Classics'",
#        "'Animals', 'Cats', 'Classics', 'Fantasy, 'Fiction', 'Picture Books', Childrens'",
#        "'Adventure', 'Classics', 'Crime', 'Espionage, 'Mystery', 'Thriller', Fiction'",
#        "'Fiction', 'France', 'Historical Fiction', 'Historical', 'Literature', 'Novels, Classics'",
#        "'Classics', 'Economics', 'History', 'Nonfiction', 'Political Science', 'Politics, Philosophy'",
#        "'Adventure', 'Classics', 'Espionage, 'Historical Fiction', 'Mystery', 'Thriller', Fiction'",
#        "'Dystopia', 'Fiction', 'Gothic, 'Horror', 'Post Apocalyptic', 'Science Fiction', Classics'",
#        "'19th Century', 'Classics', 'France', 'French Literature', 'Literature', 'Novels, Fiction'",
#        "'Classics', 'German Literature', 'Germany', 'Literature', 'Music', 'Novels, Fiction'",
#        "'Adventure', 'Fantasy', 'Fiction', 'Historical Fiction', 'Novels, 'Romance', Classics'",
#        "'Classics', 'German Literature', 'Literature', 'Novels', 'Philosophy', 'Science Fiction, Fiction'",
#        "'Childrens', 'Classics', 'Family, 'Historical Fiction', 'Kids', 'Young Adult', Fiction'",
#        "'19th Century', 'Fiction', 'France', 'French Literature', 'Novels, 'Roman', Classics'",
#        "'20th Century', 'Books About Books, 'British Literature', 'Classics', 'Literary Fiction', 'Novels', Fiction'",
#        "'Adventure', 'Animals', 'Fantasy', 'Fiction', 'Literature, 'Romance', Classics'",
#        "'Drama', 'Fiction', 'Literature, 'Plays', 'Romance', 'School', Classics'",
#        "'Adventure, 'Alternate History', 'Dinosaurs', 'Fantasy', 'Fiction', 'Science Fiction Fantasy', Science Fiction'",
#        "'Business', 'Classics, 'Finance', 'Nonfiction', 'Philosophy', 'Politics', Economics'",
#        "'19th Century', 'British Literature, 'Classics', 'Fiction', 'Literature', 'Romanticism', Poetry'",
#        "'Christmas', 'Classics', 'Crime', 'Detective, 'Fiction', 'Mystery Thriller', Mystery'",
#        "'19th Century', 'Fantasy', 'Fiction', 'Gothic', 'Horror', 'Religion, Classics'",
#        "'Ancient, 'Classics', 'History', 'Nonfiction', 'Politics', 'School', Philosophy'",
#        "'Classics', 'Fantasy', 'Fiction', 'Mystery', 'Paranormal', 'Pulp, Horror'",
#        "'Adventure', 'Classics', 'Historical Fiction', 'Literature', 'School, 'Young Adult', Fiction'",
#        "'Classics', 'Essays', 'Nonfiction', 'Religion, 'Science', 'Sociology', Philosophy'",
#        "'18th Century, 'American', 'Fiction', 'Gothic', 'Horror', 'Literature', Classics'",
#        "'Chapter Books, 'Classics', 'Fiction', 'Middle Grade', 'Mystery', 'Young Adult', Childrens'",
#        "'American, 'Classics', 'Historical Fiction', 'Literature', 'Novels', 'Religion', Fiction'",
#        "'Adventure', 'Childrens', 'Fiction', 'Historical Fiction', 'Literature', 'Young Adult, Classics'",
#        "'Adventure', 'Classics', 'Fantasy', 'Fiction', 'France', 'Literature, Science Fiction'",
#        "'Adventure', 'Africa', 'Fantasy', 'Fiction', 'Pulp', 'Science Fiction, Classics'",
#        "'18th Century, 'Essays', 'Fiction', 'Humor', 'Literature', 'Philosophy', Classics'",
#        "'Crime', 'Fiction', 'Horror', 'Mystery', 'Paranormal, 'Thriller', Fantasy'",
#        "'Audiobook, 'Fantasy', 'Fiction', 'Gothic', 'Horror', 'Short Stories', Classics'",
#        "'Economics', 'History', 'Nonfiction', 'Politics', 'Sociology', 'Theory, Philosophy'",
#        "'Drama, 'Fiction', 'Literature', 'Plays', 'Poetry', 'Short Stories', Classics'",
#        "'Ancient History', 'Classics', 'Historical', 'Nonfiction', 'Politics', 'World History, History'",
#        "'Classics', 'Czech Literature, 'German Literature', 'Literature', 'Novels', 'Philosophy', Fiction'",
#        'nan',
#        "'Ancient, 'Fantasy', 'Fiction', 'Literature', 'Mythology', 'Poetry', Classics'",
#        "'Fantasy, 'Fiction', 'Literature', 'Philosophy', 'Poetry', 'Religion', Classics'",
#        "'Classics, 'Nonfiction', 'Philosophy', 'Psychoanalysis', 'Religion', 'Science', Psychology'",
#        "'Classics', 'Fiction', 'Literature', 'Romance', 'School, 'Theatre', Plays'",
#        "'American History, 'Autobiography', 'Classics', 'History', 'Memoir', 'Nonfiction', Biography'",
#        "'Fantasy', 'Fiction', 'Literature, 'Poetry', 'Romance', 'School', Plays'",
#        "'19th Century', 'British Literature, 'Fiction', 'Historical Fiction', 'Literature', 'Romance', Classics'",
#        "'Classics', 'Fiction', 'Gothic, 'Mystery Thriller', 'Novels', 'Thriller', Mystery'",
#        "'History', 'Philosophy, 'Russia', Nonfiction'",
#        "'Biography', 'Classics', 'France', 'Literature, 'Memoir', 'Travel', Nonfiction'",
#        "'20th Century', 'American', 'Classics', 'College, 'School', 'The United States Of America', Poetry'",
#        "'Classics', 'Fiction', 'India', 'Indian Literature', 'Literature, 'Philosophy', Poetry'",
#        "'Audiobook', 'Christmas', 'Classics', 'Fantasy', 'Historical Fiction, 'Literature', Fiction'",
#        "'Ancient, 'Classics', 'History', 'Nonfiction', 'Politics', 'Reference', Philosophy'",
#        "'Classics, 'Fantasy', 'Fiction', 'Mystery', 'Short Stories', 'Weird Fiction', Horror'",
#        "'Classics', 'German Literature', 'Germany', 'LGBT, 'Literature', 'Novels', Fiction'",
#        "'Essays', 'Literature, 'Nature', 'Nonfiction', 'Philosophy', 'Politics', Classics'",
#        "'Classics', 'German Literature', 'History', 'Metaphysics, 'Nonfiction', 'Theory', Philosophy'",
#        "'Christianity', 'Classics', 'History', 'Nonfiction, 'Reference', 'Theology', Religion'",
#        "'Adventure', 'American, 'Fiction', 'Historical Fiction', 'Literature', 'Novels', Classics'",
#        "'Fiction', 'Historical Fiction', 'Italian Literature', 'Italy', 'Literature', 'Romance, Classics'",
#        "'Fiction', 'Historical Fiction', 'Literature, 'Short Stories', 'Spain', 'Travel', Classics'",
#        "'Arthurian', 'Classics', 'Fiction', 'Historical Fiction', 'Historical, 'Mythology', Fantasy'",
#        "'Adventure', 'Animals, 'Childrens', 'Fantasy', 'Fiction', 'Short Stories', Classics'",
#        "'Chapter Books, 'Childrens', 'Classics', 'Dragons', 'Fiction', 'Middle Grade', Fantasy'",
#        "'19th Century', 'Classics', 'France', 'French Literature', 'Literature', 'Romance, Fiction'",
#        "'Fiction', 'France', 'French Literature', 'Historical Fiction', 'Literature', 'Novels, Classics'",
#        "'Animals', 'Classics', 'Fantasy', 'Fiction', 'Picture Books', 'Short Stories, Childrens'",
#        "'18th Century', 'Classics', 'Nonfiction', 'Psychology', 'School, 'Science', Philosophy'",
#        "'Classics', 'History, 'Mathematics', 'Nonfiction', 'Philosophy', 'Physics', Science'",
#        "'Classics', 'Literature', 'Politics', 'Science Fiction', 'Time Travel, 'Utopia', Fiction'",
#        "'Classics', 'High School', 'Historical Fiction', 'Historical, 'Literature', 'School', Fiction'",
#        "'Chick Lit', 'Contemporary', 'Drama, 'Fiction', 'Historical Fiction', 'Historical', Romance'",
#        "'Fiction, 'Paranormal', 'Romance', 'Urban Fantasy', 'Vampires', 'Young Adult', Fantasy'",
#        'Romance;Romance,Contemporary Romance;Contemporary;Category Romance,Harlequin;Fiction;War,Military Fiction;Womens Fiction,Chick Lit;Romance,Romantic Suspense;Romance,Category Romance;Adult',
#        "'Adventure', 'Childrens', 'Fantasy', 'Fiction', 'Nobel Prize, 'Swedish Literature', Classics'",
#        "'Antisemitism, 'Historical', 'History', 'Nonfiction', 'Philosophy', 'Religion', Politics'",
#        'Philosophy;Psychology;Nonfiction;History;Sociology;Religion;Politics;Religion,Theology;Philosophy,Theory;Academic',
#        "'Childrens', 'Classics', 'Fiction', 'Historical Fiction', 'Middle Grade', 'Young Adult, Fantasy'",
#        "'Fantasy', 'Fiction', 'Gothic', 'Horror', 'Literature', 'Novels, Classics'",
#        "'20th Century, 'British Literature', 'Fiction', 'Historical Fiction', 'Literature', 'Novels', Classics'",
#        "'Classics', 'Contemporary', 'German Literature', 'Literature', 'New York, 'Novels', Fiction'",
#        "'Ancient History', 'Ancient, 'Biography', 'Classics', 'Nonfiction', 'Philosophy', History'",
#        "'19th Century', 'Fiction', 'Gothic', 'Historical Fiction', 'Historical, 'Literature', Classics'",
#        "'Classics', 'Drama', 'Fiction', 'Historical Fiction', 'Read For School, 'School', Plays'",
#        "'British Literature', 'Classics', 'Historical Fiction', 'Historical, 'Literature', 'Romance', Fiction'",
#        "'Classics', 'Fiction', 'France', 'French Literature, 'Gothic', 'Short Stories', Horror'",
#        "'Classics', 'France', 'French Literature', 'Literature', 'Novels, 'Philosophy', Fiction'",
#        "'18th Century', 'British Literature, 'Fiction', 'Gothic', 'Literature', 'Mystery', Classics'",
#        "'Childrens', 'Fiction', 'Historical Fiction', 'Historical, 'Middle Grade', 'Young Adult', Classics'",
#        "'Childrens, 'Fiction', 'Historical Fiction', 'Historical', 'Romance', 'Young Adult', Classics'",
#        "'Fiction', 'Literature, 'Novels', 'Philosophy', 'Spain', 'Spanish Literature', Classics'",
#        "'Adventure', 'Classics', 'Espionage', 'Historical Fiction', 'Mystery', 'Thriller, Fiction'",
#        "'Christian Fiction', 'Christian', 'Christianity', 'Classics', 'Religion', 'Theology, Fiction'",
#        "'19th Century', 'American', 'Fiction', 'Historical Fiction', 'Literature', 'School, Classics'",
#        "'Adventure', 'American', 'Canada', 'Classics', 'Fiction', 'Westerns, Short Stories'",
#        "'20th Century', 'American', 'Classics', 'Fiction', 'Literature', 'The United States Of America, Poetry'",
#        "'19th Century', 'Fiction', 'Historical Fiction', 'Literature', 'Novels, 'Victorian', Classics'",
#        "'20th Century', 'British Literature', 'Fiction', 'Historical Fiction', 'Literature, 'Novels', Classics'",
#        "'19th Century', 'Fiction', 'Historical Fiction', 'Literature', 'Romance', 'Victorian, Classics'",
#        "'20th Century, 'American', 'Classics', 'Literary Fiction', 'Literature', 'Short Stories', Fiction'",
#        "'Classics', 'Drama', 'Feminism, 'Fiction', 'Humor', 'Theatre', Plays'",
#        "'19th Century', 'Audiobook', 'Classic Literature, 'Historical Fiction', 'Historical', 'Literature', Fiction'",
#        "'Adventure', 'Fiction, 'Young Adult', Historical Fiction'",
#        "'19th Century', 'American', 'Classics', 'Feminism, 'Fiction', 'Literature', Poetry'",
#        "'20th Century, 'Classics', 'German Literature', 'Germany', 'Literature', 'Short Stories', Fiction'",
#        "'Adventure', 'Childrens', 'Fiction', 'Historical Fiction', 'Literature, 'Young Adult', Classics'",
#        "'Civil War', 'Fiction', 'Historical Fiction', 'Historical, 'Literature', 'War', Classics'",
#        "'Childrens, 'Historical Fiction', 'Historical', 'Literature', 'Romance', 'Young Adult', Fiction'",
#        "'Animals', 'Childrens', 'Fantasy', 'Fiction', 'Nature, 'Young Adult', Classics'",
#        "'Catholic', 'Christian', 'Faith, 'Nonfiction', 'Reference', 'Theology', Religion'",
#        "'Classics', 'Fiction', 'Historical', 'Poland', 'Polish Literature', 'War, Historical Fiction'",
#        "'19th Century, 'Adventure', 'American', 'Fiction', 'Literature', 'Short Stories', Classics'",
#        "'20th Century, 'American', 'Fiction', 'Historical Fiction', 'Literature', 'Novels', Classics'",
#        "'Fiction', 'France', 'French Literature', 'Gothic, 'Historical Fiction', 'Literature', Classics'",
#        "'Classics', 'Drama', 'Fiction', 'Literature, 'Poetry', 'Theatre', Plays'",
#        "'Classics', 'History', 'Nonfiction', 'Philosophy', 'Politics', 'Womens, Feminism'",
#        "'Christianity', 'Classics', 'Nonfiction, 'Reference', 'Spirituality', 'Theology', Religion'",
#        "'Africa', 'Classics', 'Historical Fiction', 'Literature', 'Novels, 'School', Fiction'",
#        "'Animals, 'Childrens', 'Fantasy', 'Fiction', 'Picture Books', 'Short Stories', Classics'",
#        "'19th Century, 'Classics', 'Fiction', 'France', 'French Literature', 'Literature', Poetry'",
#        "'Adventure', 'Cats', 'Fantasy', 'Fiction', 'Science Fiction Fantasy', 'Young Adult, Science Fiction'",
#        "'19th Century', 'Classics', 'Historical Fiction', 'Literature', 'Novels, 'Romance', Fiction'",
#        "'Classics', 'German Literature', 'Metaphysics', 'Nonfiction', 'Read For School, 'School', Philosophy'",
#        "'19th Century, 'Classics', 'Fiction', 'French Literature', 'Literature', 'Poetry', France'",
#        'Fantasy;Fiction;Young Adult;Childrens;Fantasy,Magic;Science Fiction Fantasy;Novels;Childrens,Middle Grade;European Literature,British Literature;Reference',
#        "'American', 'Banned Books, 'Fiction', 'Historical Fiction', 'Literature', 'Novels', Classics'",
#        "'19th Century', 'American', 'Fiction', 'Historical Fiction', 'Literature', 'Romance, Classics'",
#        "'Adventure', 'Childrens, 'Fiction', 'Historical Fiction', 'Literature', 'Young Adult', Classics'",
#        "'Catholic, 'Fiction', 'France', 'Historical Fiction', 'Historical', 'Literature', Classics'",
#        "'Fantasy, 'Fiction', 'Italian Literature', 'Literature', 'Poetry', 'Religion', Classics'",
#        "'Fiction', 'Gothic', 'Horror', 'Music', 'Mystery', 'Victorian, Classics'",
#        "'Classics', 'Nonfiction', 'Personal Development', 'Philosophy', 'Psychology', 'Spirituality, Self Help'",
#        "'Classics', 'History', 'Memoir', 'Philosophy', 'Poetry, Nonfiction'",
#        "'Audiobook', 'Classics', 'Crime', 'Detective, 'Fiction', 'Mystery Thriller', Mystery'",
#        "'19th Century', 'Classic Literature, 'Fiction', 'Historical Fiction', 'Literature', 'Novels', Classics'",
#        "'Childrens', 'Fairy Tales', 'Fantasy', 'Fiction', 'Literature, 'Short Stories', Classics'",
#        "'American History', 'Classics', 'Nonfiction', 'Philosophy', 'Political Science, 'Politics', History'",
#        "'Fiction', 'Gothic', 'Horror', 'Mystery', 'Short Stories', 'Victorian, Classics'",
#        "'Crime', 'Fiction', 'Gothic, 'Horror', 'Mystery', 'Short Stories', Classics'",
#        "'Ancient, 'Epic', 'Greek Mythology', 'Historical Fiction', 'Historical', 'Literature', Mythology'",
#        "'Animals', 'Childrens', 'Fiction', 'Historical Fiction, 'Horses', 'Young Adult', Classics'",
#        "'Adventure', 'American, 'Fiction', 'Historical Fiction', 'Historical', 'Literature', Classics'",
#        "'Horror', 'Literature', 'Novels, 'Philosophy', 'School', 'Short Stories', Fantasy'",
#        "'Classics', 'Historical Fiction, 'Italian Literature', 'Italy', 'Literature', 'Short Stories', Fiction'",
#        "'Classics, 'Fiction', Short Stories'",
#        "'Classics', 'Fantasy', 'Fiction', 'Mystery, 'Short Stories', 'Vampires', Horror'",
#        "'Essays', 'History', 'Modern', 'Nonfiction', 'Politics', 'The United States Of America, Philosophy'",
#        'Animals',
#        "'Classics', 'Fantasy, 'Fiction', 'Gothic', 'Horror', 'Short Stories', Poetry'",
#        "'Cyberpunk', 'Dystopia', 'Fiction', 'Science Fiction', 'Teen', 'Thriller, Young Adult'",
#        "'Classics', 'Fiction', 'Historical Fiction', 'Horror', 'Literature', 'War, Short Stories'",
#        "'Classics', 'German Literature', 'Germany, 'Literature', 'Novels', 'Philosophy', Fiction'",
#        "'History', 'Nonfiction', 'Personal Development, 'Psychology', 'Self Help', 'Spirituality', Philosophy'",
#        "'18th Century', 'Fantasy', 'Fiction', 'Gothic', 'Horror', 'Literature, Classics'",
#        "'20th Century', 'Classics', 'Fiction', 'Literary Fiction', 'Literature', 'Womens, Short Stories'",
#        "'Classics', 'Feminism', 'Fiction', 'Gothic', 'Horror', 'Mental Health, Short Stories'",
#        "'Autobiography', 'Biography', 'Memoir, 'Nonfiction', 'Philosophy', 'Religion', Spirituality'",
#        "'Fiction', 'Splatterpunk', 'Supernatural, 'Thriller', Horror'",
#        "'20th Century', 'American', 'Classics', 'Literary Fiction, 'Literature', 'Short Stories', Fiction'",
#        "'Audiobook', 'Classic Literature, 'Fiction', 'Historical Fiction', 'Historical', 'Literature', Classics'",
#        "'Adventure', 'American', 'Fiction', 'Historical Fiction', 'Historical, 'Literature', Classics'",
#        "'Classics', 'Fantasy', 'Fiction', 'Gothic', 'Paranormal, 'Vampires', Horror'",
#        "'Crime', 'Detective', 'Fiction', 'Mystery Thriller, 'Mystery', 'Short Stories', Classics'",
#        "'American', 'Fiction', 'Gothic', 'Historical Fiction', 'Horror, 'Literature', Classics'",
#        "'20th Century, 'Fiction', 'France', 'French Literature', 'Literature', 'Novels', Classics'",
#        "'Classics', 'Fiction', 'German Literature', 'Literary Fiction, 'Literature', 'Philosophy', Short Stories'",
#        "'19th Century', 'British Literature, 'Classics', 'Humor', 'Literature', 'Victorian', Fiction'",
#        "'Childrens', 'Classics', 'Fantasy', 'Literature', 'Mythology, 'Short Stories', Fiction'",
#        "'Adventure', 'Fiction', 'France', 'Historical Fiction', 'Historical, 'Literature', Classics'",
#        "'18th Century', 'British Literature, 'Fiction', 'Humor', 'Literature', 'Novels', Classics'",
#        "'Drama', 'Fiction', 'France', 'Plays', 'Romance', 'Theatre, Classics'",
#        "'Classics', 'Nonfiction', 'Philosophy', 'Psychoanalysis', 'Science', 'Theory, Psychology'",
#        "'Adventure', 'Childrens', 'Fiction', 'Historical Fiction', 'Historical, 'Young Adult', Classics'",
#        "'Classics', 'German Literature', 'Germany', 'Historical Fiction', 'Novels, 'War', Fiction'",
#        "'19th Century', 'Fiction', 'Gothic', 'Historical Fiction', 'Romance, 'Scotland', Classics'",
#        "'Adventure', 'Fiction', 'France', 'French Literature', 'Historical Fiction', 'Roman, Classics'",
#        "'Essays', 'Fiction', 'Humor', 'Philosophy', 'School, 'Short Stories', Classics'",
#        "'Anthologies', 'Fantasy', 'Fiction', 'Occult, 'Short Stories', 'Supernatural', Horror'",
#        "'Classics', 'Fantasy', 'Fiction', 'Literature', 'Philosophy, 'Religion', Poetry'",
#        "'Contemporary', 'Historical Fiction', 'Humor', 'Literature, 'Novels', 'Politics', Fiction'",
#        "'Audiobook, 'Crime', 'Detective', 'Fiction', 'Mystery', 'Short Stories', Classics'",
#        "'American', 'Americana', 'Classics', 'Fiction', 'Literature', 'The United States Of America, Poetry'",
#        "'Classics', 'Essays', 'Humor', 'Literature, 'Religion', 'Short Stories', Fiction'",
#        "'19th Century', 'Fiction', 'Historical Fiction, 'Literature', 'Novels', 'Victorian', Classics'",
#        "'20th Century, 'France', 'French Literature', 'Literature', 'Novels', 'Philosophy', Fiction'",
#        "'Africa', 'Autobiography, 'Biography', 'Classics', 'Memoir', 'Nonfiction', History'",
#        "'Adventure', 'Fiction', 'Historical Fiction', 'Literature', 'Novels, 'Spanish Literature', Classics'",
#        "'Autobiography, 'Biography', 'Classics', 'History', 'Memoir', 'School', Nonfiction'",
#        "'20th Century, 'Classics', 'Ireland', 'Irish Literature', 'Literature', 'Novels', Fiction'",
#        "'Adventure, 'Childrens', 'Classics', 'Fiction', 'Literature', 'Young Adult', Fantasy'",
#        'Mystery',
#        "'Classics', 'Fiction', 'Literature', 'Plays', 'Romance', 'School, Poetry'",
#        "'20th Century, 'Fiction', 'Ireland', 'Irish Literature', 'Literature', 'Short Stories', Classics'",
#        "'19th Century', 'Audiobook, 'Fiction', 'Historical Fiction', 'Historical', 'Literature', Classics'",
#        "'20th Century', 'Classics', 'Historical Fiction', 'Literature', 'Novels, 'Russia', Fiction'",
#        "'18th Century', 'British Literature', 'Fiction', 'Humor', 'Literature', 'Novels, Classics'",
#        "'Audiobook', 'British Literature, 'Fiction', 'Historical Fiction', 'Italy', 'Romance', Classics'",
#        "'Adventure', 'Childrens', 'Classics', 'Fiction', 'Middle Grade, 'Young Adult', Fantasy'",
#        "'Classic Literature', 'Fantasy', 'Literary Fiction', 'Magical Realism', 'Novels, 'Short Story Collection', Short Stories'",
#        "'Fiction', 'Gothic', 'Horror', 'Literature, 'Mystery', 'Short Stories', Classics'",
#        "'Ancient', 'Classics', 'Greece, 'History', 'Nonfiction', 'School', Philosophy'",
#        "'Adventure', 'Childrens', 'Fiction', 'Historical Fiction, 'Literature', 'Young Adult', Classics'",
#        "'British Literature', 'Classics', 'Fiction', 'Literature', 'Philosophy, 'Romanticism', Poetry'",
#        "'Fantasy, 'Fiction', 'Gothic', 'Horror', 'Mystery', 'Short Stories', Classics'",
#        "'Fiction', 'Historical Fiction, 'Horror', 'Read For School', 'School', 'Short Stories', Classics'",
#        "'American', 'Classics', 'Fiction', 'Literature', 'Read For School, 'School', Poetry'",
#        "'Classics', 'Drama', 'Fiction', 'Historical Fiction', 'Poetry, 'Theatre', Plays'",
#        "'Audiobook', 'Crime', 'Detective', 'Fiction', 'Mystery Thriller, 'Mystery', Classics'",
#        "'Autobiography, 'Biography', 'Classics', 'Historical', 'History', 'Memoir', Nonfiction'",
#        "'Crime', 'Fiction', 'France', 'Mystery Thriller, 'Mystery', 'Short Stories', Classics'",
#        "'Classics', 'Essays', 'History, 'Literature', 'Nonfiction', 'Poetry', Philosophy'",
#        "'19th Century', 'British Literature, 'Classics', 'Literature', 'Romance', 'Victorian', Fiction'",
#        "'Classics', 'Essays', 'Language', 'Nonfiction', 'Psychology', 'Science, Philosophy'",
#        "'Classic Literature, 'Fiction', 'Historical Fiction', 'Historical', 'Literature', 'Romance', Classics'",
#        "'Classics', 'Essays', 'Logic', 'Nonfiction', 'Religion', 'Science, Philosophy'",
#        "'American History', 'Classics', 'Essays, 'Nonfiction', 'Philosophy', 'Politics', History'",
#        "'Fiction', 'Mythology', 'Plays', 'Read For School', 'School', 'Theatre, Classics'",
#        "'19th Century, 'Classics', 'France', 'French Literature', 'Literature', 'Romance', Fiction'",
#        "'Fiction', 'Gothic', 'Horror', 'Mystery, 'School', 'Short Stories', Classics'",
#        "'Classics', 'Fiction', 'Literature', 'Philosophy', 'Short Stories', 'Spirituality, Poetry'",
#        "'Nonfiction, Poetry'",
#        "'Audiobook', 'Fiction', 'Gothic', 'Horror', 'Literature, 'Mystery', Classics'",
#        "'Classics', 'Fiction', 'War, Historical Fiction'",
#        "'American, 'Fiction', 'Historical Fiction', 'Historical', 'Literature', 'Novels', Classics'",
#        "'Feminism', 'Fiction', 'Historical Fiction', 'Literature', 'Read For School, 'School', Classics'",
#        "'Classics, History'",
#        "'Anthropology', 'Genetics, 'Nonfiction', 'Politics', 'Race', 'Research', History'",
#        "'Classics', 'Comedy, 'Language', 'Nonfiction', 'Philosophy', 'Reference', Humor'",
#        "'Childrens', 'Classics', 'Fairy Tales', 'Fiction', 'Middle Grade', 'Young Adult, Fantasy'",
#        "'Adventure', 'Fiction', 'Historical Fiction', 'Historical', 'Pirates', 'Romance, Classics'",
#        "'Ancient History', 'Ancient', 'Classics', 'Greece', 'Nonfiction', 'Philosophy, History'",
#        "'Art', 'British Literature', 'Criticism, 'Music', 'Nonfiction', Essays'",
#        "'Audiobook', 'Classics', 'Crime', 'Detective', 'Fiction', 'Thriller, Mystery'",
#        "'Christian', 'Faith', 'Inspirational', 'Religion, Nonfiction'",
#        "'18th Century', 'British Literature, 'Fiction', 'Literature', 'Novels', 'Romance', Classics'",
#        "'Fiction', 'Gothic, 'Horror', 'Mystery', 'Poetry', 'Short Stories', Classics'",
#        "'Buddhism, 'Fiction', 'Literature', 'Philosophy', 'Religion', 'Spirituality', Classics'",
#        "'Cultural, 'India', 'Nonfiction', 'Poetry', 'Religion', 'Spirituality', Philosophy'",
#        "'Audiobook', 'Crime', 'Detective, 'Fiction', 'Mystery Thriller', 'Thriller', Mystery'",
#        "'Classics', 'Fiction', 'Gothic', 'Mystery', 'Short Stories', 'Weird Fiction, Horror'",
#        "'British Literature, 'Crime', 'Fiction', 'Mystery Thriller', 'Plays', 'Short Stories', Mystery'",
#        "'Arthurian', 'Childrens', 'Classics', 'Fiction', 'Science Fiction Fantasy, 'Young Adult', Fantasy'",
#        "'Fiction', 'Literature, 'Mythology', 'Plays', 'Poetry', 'Theatre', Classics'",
#        "'Classics', 'Nonfiction', 'Philosophy', 'Psychoanalysis', 'Sociology', 'Theory, Psychology'",
#        "'Classics, 'Fantasy', 'Fiction', 'Gothic', 'Short Stories', 'Weird Fiction', Horror'",
#        "'Childrens', 'Classics', 'Fiction', 'Holiday, 'Picture Books', 'Poetry', Christmas'",
#        "'Classics, 'Essays', 'Nonfiction', 'Personal Development', 'Psychology', 'Self Help', Philosophy'",
#        "'Classics', 'Fairy Tales, 'Fantasy', 'Literature', 'Mythology', 'Short Stories', Fiction'",
#        "'Adventure', 'Fiction', 'France', 'French Literature', 'Historical Fiction', 'Historical, Classics'",
#        "'Adventure', 'Biography, 'Classics', 'Memoir', 'Nonfiction', 'Travel', Nature'",
#        "'20th Century', 'Australia, 'Fiction', 'Germany', 'Historical Fiction', 'Music', Classics'",
#        "'American', 'Classic Literature, 'Classics', 'Collections', 'Fiction', 'Literature', Poetry'",
#        "'Adventure', 'Classics', 'Fantasy', 'Fiction', 'Pulp', 'Science Fiction Fantasy, Science Fiction'",
#        "'Autobiography, 'Biography', 'Feminism', 'History', 'Memoir', 'Politics', Nonfiction'",
#        "'Anthologies', 'Fiction', 'Science Fiction Fantasy', 'Science Fiction', 'Short Stories', 'Speculative Fiction, Cyberpunk'",
#        "'Adventure', 'English Literature, 'Fantasy', 'Fiction', 'Humor', 'Literature', Classics'",
#        "'Animals', 'Childrens', 'Fantasy', 'Fiction', 'Picture Books', 'Young Adult, Classics'",
#        "'Classics', 'Crime', 'Detective', 'Fiction', 'Mystery Thriller', 'Thriller, Mystery'",
#        "'Christian, 'Christmas', 'Classics', 'Literature', 'Religion', 'Short Stories', Fiction'",
#        "'Erotica', 'Fiction', 'France', 'French Literature, 'Horror', 'Philosophy', Classics'",
#        "'Fiction', 'Ghosts, 'Gothic', 'Horror', 'Literature', 'Short Stories', Classics'",
#        "'Classics', 'Fiction', 'Ghost Stories, 'Ghosts', 'Gothic', 'Short Stories', Horror'",
#        "'18th Century, 'Adventure', 'Classics', 'Historical Fiction', 'Literature', 'Novels', Fiction'",
#        "'Fantasy', 'Fiction', 'Literature', 'Mythology', 'Poetry', 'School, Classics'",
#        "'Fiction', 'Gothic', 'Horror', 'Literature, 'Poetry', 'Short Stories', Classics'",
#        "'American, 'Fiction', 'Historical Fiction', 'Literature', 'Romance', 'School', Classics'",
#        "'Autobiography', 'Biography Memoir', 'Biography', 'Classics, 'History', 'Memoir', Nonfiction'",
#        "'Classics', 'History', 'Literature, 'Medieval', 'Nonfiction', 'Poetry', Mythology'",
#        "'Classics', 'Fantasy', 'Fiction', 'Gothic, 'Short Stories', 'Weird Fiction', Horror'",
#        "'Africa', 'Fiction', 'Historical Fiction', 'Literature', 'Novels, 'School', Classics'",
#        "'Childrens, 'Fantasy', 'Fiction', 'Literature', 'Romance', 'Short Stories', Classics'",
#        "'Fiction', 'Historical Fiction', 'Historical, 'Japan', 'Japanese Literature', 'Literature', Classics'",
#        "'Classics', 'Historical Fiction', 'India', 'Indian Literature', 'Literature, 'Novels', Fiction'",
#        "'Classics', 'History', 'Literature, 'Nonfiction', 'Politics', 'School', Philosophy'",
#        "'19th Century', 'Fiction', 'France', 'French Literature', 'Literature', 'Novels, Classics'",
#        "'Childrens', 'Fiction', 'Historical Fiction', 'Historical, 'Romance', 'Young Adult', Classics'",
#        "'18th Century', 'Classics', 'Drama', 'Fiction', 'Humor, 'Theatre', Plays'",
#        "'Classics', 'Fantasy', 'Fiction', 'Mystery, 'Pirates', 'Weird Fiction', Horror'",
#        "'Classics', 'Essays, 'Nonfiction', 'Philosophy', 'Psychoanalysis', 'Science', Psychology'",
#        "'Childrens', 'Fiction', 'Historical Fiction', 'Novels, 'Romance', 'Young Adult', Classics'",
#        "'Fantasy', 'Paranormal Romance', 'Paranormal', 'Romance', 'Supernatural, 'Young Adult', Vampires'",
#        "'Adventure', 'Fiction', 'High Fantasy, 'Science Fiction Fantasy', 'Science Fiction', 'Speculative Fiction', Fantasy'",
#        "'Adult', 'Classics', 'Contemporary', 'Dark, 'Poetry', 'Romance', Fiction'",
#        "'Fantasy', 'Feminism, 'Fiction', 'Historical Fiction', 'LGBT', 'Queer', Classics'",
#        "'Classics', 'Essays', 'German Literature, 'Nonfiction', 'Philosophy', 'Writing', Poetry'",
#        "'Art', 'Biography', 'Classics', 'LGBT', 'Memoir', 'Queer, Nonfiction'",
#        "'Adventure', 'Classics', 'Fiction', 'Historical Fiction', 'Historical, 'Romance', Westerns'",
#        "'Classics', 'History', 'Nonfiction', 'Politics, 'Reference', 'Religion', Philosophy'"],
#       dtype=object)

# %%
import requests

def fetch_book_info(isbn):
    url = f"https://www.googleapis.com/books/v1/volumes?q=isbn:{isbn}"
    response = requests.get(url)

    if response.status_code != 200:
        return None

    data = response.json()

    if "items" not in data:
        return None

    info = data["items"][0]["volumeInfo"]

    return {
        "title": info.get("title"),
        "authors": info.get("authors", []),
        "thumbnail": info.get("imageLinks", {}).get("thumbnail"),
        "description": info.get("description"),
        "categories": info.get("categories", []),
        "publishedDate": info.get("publishedDate"),
        "pageCount": info.get("pageCount"),
    }

# %%
def enrich_with_google_books(df):
    df = df.copy()

    new_covers = []
    new_titles = []
    new_authors = []
    new_categories = []
    new_desc = []

    for isbn in df["isbn13"]:
        result = fetch_book_info(isbn)

        if result:
            new_covers.append(result["thumbnail"])
            new_titles.append(result["title"])
            new_authors.append(", ".join(result["authors"]))
            new_categories.append(", ".join(result["categories"]))
            new_desc.append(result["description"])
        else:
            new_covers.append(None)
            new_titles.append(None)
            new_authors.append(None)
            new_categories.append(None)
            new_desc.append(None)

    df["gb_title"] = new_titles
    df["gb_author"] = new_authors
    df["gb_categories"] = new_categories
    df["gb_description"] = new_desc
    df["gb_cover"] = new_covers

    return df

# %%
# =====================================================
# 0️⃣ Imports e setup
# =====================================================
import os, joblib, numpy as np, pandas as pd
from pathlib import Path
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import normalize
from sklearn.decomposition import TruncatedSVD
from scipy.sparse import save_npz
import matplotlib.pyplot as plt

# Caminhos
DATA_PATH = Path("/home/rafael/Área de Trabalho/CUROS IRONHACK/SEMANA 10/get_your_book/data/raw/processed")
INPUT_CSV = DATA_PATH / "books_final_version_cleaned.csv"
OUTPUT_DIR = DATA_PATH / "ml_outputs"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# =====================================================
# 1️⃣ Carregar dataset limpo
# =====================================================
df = pd.read_csv(INPUT_CSV)
print("Shape:", df.shape)
print(df.columns.tolist())

# =====================================================
# 2️⃣ Criar campo de texto para NLP
# =====================================================
for col in ["title", "author", "genre", "description"]:
    df[col] = df[col].fillna("").astype(str)

df["text"] = df["title"] + ". " + df["author"] + ". " + df["genre"] + ". " + df["description"]

# =====================================================
# 3️⃣ Vetorização TF-IDF
# =====================================================
vectorizer = TfidfVectorizer(
    stop_words="english",
    ngram_range=(1, 2),
    max_df=0.9,
    min_df=3,
    max_features=20000
)
X = vectorizer.fit_transform(df["text"])
X_norm = normalize(X, norm="l2", copy=True)

print("TF-IDF shape:", X.shape)

# =====================================================
# 4️⃣ Teste de K (Silhouette e Elbow)
# =====================================================
Ks = list(range(4, 13))
scores = {}
inertias = {}

for k in Ks:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    labels = kmeans.fit_predict(X)
    inertias[k] = kmeans.inertia_  # soma das distâncias quadradas
    score = silhouette_score(X, labels, sample_size=min(2000, X.shape[0]), random_state=42)
    scores[k] = score
    print(f"k={k}: silhouette={score:.4f}, inertia={inertias[k]:,.0f}")

best_k = max(scores, key=scores.get)
print(f"\n✅ Melhor K = {best_k}  (Silhouette = {scores[best_k]:.4f})")


# 5️⃣ Visualizar gráficos

plt.figure(figsize=(12,5))

# Gráfico 1: Silhouette Score
plt.subplot(1,2,1)
plt.plot(Ks, [scores[k] for k in Ks], marker="o", color="royalblue")
plt.title("Silhouette Score by numbers of clusters (KMeans)")
plt.xlabel("Number of clusters (k)")
plt.ylabel("Silhouette Score")
plt.grid(True)

# Gráfico 2: Elbow Method (Inertia)
plt.subplot(1,2,2)
plt.plot(Ks, [inertias[k] for k in Ks], marker="o", color="darkorange")
plt.title("Elbow Method")
plt.xlabel("Number of clusters (k)")
plt.ylabel("Inertia")
plt.grid(True)

plt.tight_layout()
plt.show()


# 6️⃣ Treinar modelo final com melhor K

kmeans_final = KMeans(n_clusters=best_k, random_state=42, n_init=10)
labels = kmeans_final.fit_predict(X)
df["cluster"] = labels


# 7️⃣ Termos representativos

feature_names = np.array(vectorizer.get_feature_names_out())
centers = kmeans_final.cluster_centers_
top_terms = []

for i in range(best_k):
    top_idx = centers[i].argsort()[-10:][::-1]
    top_terms.append(", ".join(feature_names[top_idx]))

cluster_df = pd.DataFrame({
    "cluster": range(best_k),
    "top_terms": top_terms
})

print("\n=== Cluster overview ===")
display(cluster_df)


# =====================================================
# 8️⃣ Visualização dos clusters em 2D (via SVD)
# =====================================================
print("\n🌀 Gerando gráfico de clusters em 2D...")

# Reduz de milhares de dimensões para 2D
svd = TruncatedSVD(n_components=2, random_state=42)
X_2d = svd.fit_transform(X_norm)

# DataFrame para visualização
df_plot = pd.DataFrame({
    "x": X_2d[:, 0],
    "y": X_2d[:, 1],
    "cluster": df["cluster"].astype(int)
})

# Paleta de cores clara e coerente (até 15 clusters)
import seaborn as sns
palette = sns.color_palette("tab10", n_colors=len(df_plot["cluster"].unique()))

# Plot dos clusters
plt.figure(figsize=(10, 7))
for i, c in enumerate(sorted(df_plot["cluster"].unique())):
    subset = df_plot[df_plot["cluster"] == c]
    plt.scatter(
        subset["x"],
        subset["y"],
        s=20,
        color=palette[i],
        label=f"Cluster {c}",
        alpha=0.7,
        edgecolors='none'
    )

plt.title("Book distribution (KMeans Clusters)", fontsize=14, fontweight='bold')
plt.xlabel("Component 1 (SVD)", fontsize=12)
plt.ylabel("Component 2 (SVD)", fontsize=12)

# ✅ Legenda melhorada e ordenada
plt.legend(
    title="📚 Clusters",
    title_fontsize=11,
    fontsize=10,
    loc='center left',
    bbox_to_anchor=(1.02, 0.5),
    borderaxespad=0,
    frameon=True,
    facecolor='white',
    edgecolor='gray'
)

plt.tight_layout()
plt.show()



# 9️⃣ Salvar artefatos

df_out = OUTPUT_DIR / "books_clustered.csv"
df.to_csv(df_out, index=False, encoding="utf-8")
joblib.dump(vectorizer, OUTPUT_DIR / "tfidf_vectorizer.joblib")
joblib.dump(kmeans_final, OUTPUT_DIR / "kmeans_model.joblib")
save_npz(OUTPUT_DIR / "tfidf_matrix_norm.npz", X_norm)

print(f"\n📘 Arquivos salvos em: {OUTPUT_DIR}")
# Out:
# Shape: (3347, 8)
# ['title', 'author', 'description', 'url', 'isbn13', 'genre', 'cover_image_uri', 'needs_cover']
# TF-IDF shape: (3347, 6488)
# k=4: silhouette=0.0285, inertia=2,974
# k=5: silhouette=0.0340, inertia=2,936
# k=6: silhouette=0.0362, inertia=2,915
# k=7: silhouette=0.0387, inertia=2,897
# k=8: silhouette=0.0421, inertia=2,872
# k=9: silhouette=0.0433, inertia=2,866
# k=10: silhouette=0.0336, inertia=2,865
# k=11: silhouette=0.0468, inertia=2,836
# k=12: silhouette=0.0229, inertia=2,830
#
# ✅ Melhor K = 11  (Silhouette = 0.0468)
# === Cluster overview ===
#     cluster                                          top_terms
# 0         0  new, world, life, book, history, edition, work...
# 1         1  epub digitized, book epub, proofread volunteer...
# 2         2  mystery nonfiction, art nan, occult art, nonfi...
# 3         3  fiction, fantasy, science fiction, science, ad...
# 4         4  mythology, mythology poetry, fantasy, poetry s...
# 5         5  work, important, original, scholars, united, k...
# 6         6  nonfiction, history, philosophy, philosophy na...
# 7         7  literature, fiction, nan free, classics, ficti...
# 8         8  mystery, thriller, fiction, horror, fiction my...
# 9         9  fiction, historical, fiction historical, histo...
# 10       10  century horror, plays romanticism, horror play...
# 🌀 Gerando gráfico de clusters em 2D...
# /tmp/ipykernel_13726/314289559.py:170: UserWarning: Glyph 128218 (\N{BOOKS}) missing from current font.
#   plt.tight_layout()
# /home/rafael/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128218 (\N{BOOKS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# 📘 Arquivos salvos em: /home/rafael/Área de Trabalho/CUROS IRONHACK/SEMANA 10/get_your_book/data/raw/processed/ml_outputs

# %%
print(df["cluster"].value_counts().sort_index())
# Out:
# cluster
# 0      893
# 1     1384
# 2       89
# 3      118
# 4       84
# 5       37
# 6      156
# 7      261
# 8       91
# 9      165
# 10      69
# Name: count, dtype: int64
